# %% [markdown]
# - https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
# - https://ai.intel.com/demystifying-deep-reinforcement-learning/
# - https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/
#
# - https://github.com/AndersonJo/dqn-pytorch/blob/master/dqn.py
# - https://github.com/hengyuan-hu/rainbow
# - https://github.com/transedward/pytorch-dqn

# %%
import matplotlib.pyplot as plt
import gym
import cv2
import random
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
from collections import namedtuple
import copy

# %%
SEED = 1234
CAPACITY = 10_000
BATCH_SIZE = 32
PROCESSED_SIZE = 84
GAME = 'Pong-v0'
N_ACTIONS = gym.make(GAME).action_space.n
PHI_LENGTH = 4
UPDATE_FREQ = 1
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_STEPS = 30_000
GAMMA = 0.99
TARGET_UPDATE = 1000
PRINT_UPDATE = 5_000

# %%
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class ReplayMemory:
    def __init__(self, capacity, batch_size):
        """
        Replay memory that holds examples in the form of (s, a, r, s')
        
        args:
            capacity (int): the size of the memory
            batch_size (int): size of batches used for training model
        """
        
        self.batch_size = batch_size
        self.capacity = capacity
        self.memory = deque(maxlen=self.capacity)
        self.Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state'))
        self._available = False

    def put(self, state, action, reward, next_state):
        """
        Places an (s, a, r, s') example in the memory
        
        args:
            state (np.array): 
            action (list[int]):
            reward (list[int]):
            next_state (np.array or None):
        """
        
        state = torch.FloatTensor(state)
        action = torch.LongTensor([action])
        reward = torch.FloatTensor([reward])
        if next_state is not None:
            next_state = torch.FloatTensor(next_state)
        transition = self.Transition(state=state, action=action, reward=reward, next_state=next_state)
        self.memory.append(transition)

    def sample(self):
        """
        Gets a random sample of n = batch_size examples from the memory
            
        returns:
            Transitions (namedtuple): a tuple of (s, a, r, s')
        """
        
        transitions = random.sample(self.memory, self.batch_size)
        return self.Transition(*(zip(*transitions)))

    def size(self):
        """
        Returns the length of the memory
        
        returns:
            length (int): number of examples in the memory
        """
        return len(self.memory)

    def is_available(self):
        """
        Returns True if we have enough examples within the memory
        
        returns:
            available (bool): True if we have at least n = batch_size examples in the memory
        """
        if self._available:
            return True

        if len(self.memory) > self.batch_size:
            self._available = True
        return self._available

# %%
class Environment:
    def __init__(self, game, size, seed):
        """
        A class that has helpful wrappers around the Gym environment
        
        game (string): name of Atari game, i.e. Breakout-v0
        size (int): height and width of observation after preprocessing
        seed (int): random seed
        """
        
        self.size = size
        
        #init game
        self.game = gym.make(game)
        
        #set random seed for determinism
        self.game.seed(seed)
        
    def process(self, obs):
        """
        Process an observation (i.e. convert to grayscale, resize and normalize)
        
        args:
            obs (np.array): observation from gym of game screen, should be (height, width, channels)
        
        returns:
            output (np.array): (self.size, self.size) array with all values <= 1
        """
        
        assert len(obs.shape) == 3 #make sure image is correct shape
        
        gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY) #convert to grayscale
        output = cv2.resize(gray, (self.size, self.size)) #resize
        output = output.astype(np.float32, copy=False) #convert to float32
        output /= 255.0 #normalize values between [0, 1]
                     
        assert (output <= 1.0).all() 
                        
        return output
    
    def get_obs(self):
        """
        Gets a processed observation
        
        returns:
            obs (np.array): (self.size, self.size) array with all values <= 1
        """
        
        obs = self.game.render('rgb_array')
        obs = self.process(obs)
        return obs
    
    def init(self):
        """
        Reset the environment and return the initial state (unprocessed)
        
        returns:
            obs (np.array): observation from gym of game screen, should be (height, width, channels)
        """
        obs = self.game.reset()
        return obs
    
    def reset(self):
        """
        Reset the environment and return the initial state (processed)
        
        returns:
            output (np.array): (self.size, self.size) array with all values <= 1
        """
        obs = self.game.reset()
        output = self.process(obs)
        return output

# %%
class DQN(nn.Module):

    def __init__(self, n_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(7*7*64, 512)
        self.fc2 = nn.Linear(512, n_actions) #actions from from env.action_space.n

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc1(x.view(x.size(0), -1))) #flattens the (N, C, H, W) to (N, C*H*W)
        return self.fc2(x)

# %%
class Agent:
    def __init__(self, env, mem, model, phi_length, update_freq, e_start, e_end, e_steps, gamma, target_update, print_update):
        """
        An agent class that handles training the model

        args:
            mem (ReplayMemory): ReplayMemory object
            env (Environment): Environment object
            model (nn.Module): PyTorch model
            phi_length (int): number of observations to stack to make a state
            frame_skip (int): we only use every n = frame_skip observations to make a state
            e_start (int): initial value of epsilon
            e_end (int): minimum value of epsilon
            e_steps (int): number of steps for epsilon to go from e_start to e_end
            gamma (float): decay rate of rewards
            target_update (int): after how many steps (frames) to update target model
            print_update (int): after how many steps (frames) to print summary of performance
            
        """
        self.env = env
        self.mem = mem
        self.model = model
        self.phi_length = phi_length
        self.update_freq = update_freq
        self.e_start = e_start
        self.e_end = e_end
        self.e_steps = e_steps
        self.gamma = gamma
        self.target_update = target_update
        self.print_update = print_update
        
        self.steps = 0 #number of steps taken
        self.episodes = 0 #number of episodes
        self.obs_buffer = deque(maxlen=phi_length) #for holding observations to be turned into states
        
        #put model on gpu if available
        self.model = model.to(device)
        
        #create target model
        self.target = copy.deepcopy(self.model)
    
        #create optimizer
        #self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025, alpha=0.95, momentum=0.95)
        self.optimizer = optim.Adam(self.model.parameters(), lr=1e-4)
        
    def get_epsilon(self):
        """
        Calculates the value of epsilon from the current number of frames
        
        returns:
            epsilon (int): the probability of doing a random action
        """
        epsilon = self.e_end + (self.e_start - self.e_end) * math.exp(-1. * self.steps / self.e_steps)
        return epsilon
        
    def get_action(self, state):
        """
        Selects action to perform, with probability = epsilon chooses a random action,
        else chooses the best predicted action of the model
        
        args:
            state (np.array): input state to the model
            
        returns:
            action (int): the index of the action 
        """
    
        #get value of epsilon
        epsilon = self.get_epsilon()
        
        #with probablity of epsilon, pick a random action
        if random.random() < epsilon:
            action = self.env.game.action_space.sample()
        
        else:
            #with probability of (1 - epsilon) pick predicted value
            with torch.no_grad():
                state = torch.FloatTensor(state).unsqueeze(0).to(device) #convert to tensor, reshape and add to gpu
                Qsa = self.model(state) #pass state through model to get Qa
                action = Qsa.max(1)[1].item() #action is max Qa value
                
        #make sure the value is an integer
        assert isinstance(action, int)
            
        return action
    
    def get_initial_state(self):
        """
        Get the initial state to the model, a stack of processed observations
        
        returns:
            state (np.array): a stack of n = phi_length processed observations
        """
        
        _ = self.env.reset() #reset environment
        obs = self.env.get_obs() #get a processed observation
        state = np.stack([obs for _ in range(self.phi_length)], axis=0) #stack n = phi_length times to make a state
        
        #also fill the 
        for _ in range(self.phi_length):
            self.obs_buffer.append(obs)
        
        return state
        
    def get_state(self):
        """
        Get a stack from the observation buffer
        
        returns:
            state (np.array): a stack of n = phi_length processed observations
        """
        
        state = np.array(self.obs_buffer)
        
        return state
        
    def train(self):
        
        training_done = False
        reward_per_episode = []
        rewards_all_episodes = []
        
        while not training_done:
            
            episode_done = False
            episode_reward = 0
            episode_steps = 0
            
            #get initial state
            state = self.get_initial_state()
            
            while not episode_done:
                                
                #get action
                action = self.get_action(state)
                               
                #apply action while skipping frames
                observation, reward, episode_done, info = self.env.game.step(action)

                #sum rewards
                episode_reward += reward
                    
                #append processed observation to a buffer of observations
                self.obs_buffer.append(self.env.get_obs())
                        
                #get the next state from the observation buffer
                next_state = self.get_state()
                               
                #add to memory, for terminal states, set next_state to None
                if episode_done:
                    mem.put(state, action, reward, None)
                else:
                    mem.put(state, action, reward, next_state)
                    
                #make new state the old next_state
                state = next_state
                                
                #increase number of steps
                self.steps += 1
                episode_steps += 1 
            
                #update model parameters
                if mem.is_available() and self.steps % self.update_freq == 0 and self.steps > 10_000:
                    loss = self.optimize()
            
                if self.steps % (self.target_update*self.update_freq) == 0 and self.steps > 10_000:
                    self.target.load_state_dict(self.model.state_dict())
            
                if self.steps % self.print_update == 0:
                    avg_reward_per_episode = np.mean(reward_per_episode)
                    #rewards_all_episodes.extend(reward_per_episode)
                    reward_per_episode = []
                    print(f'Episodes: {self.episodes}, Steps: {self.steps}, Epsilon: {self.get_epsilon():.2f}, Avg. Reward per Ep: {avg_reward_per_episode:.2f}')

            #increase number of episodes
            self.episodes += 1
            reward_per_episode.append(episode_reward)
                            
    
    def optimize(self):
        """
        Update model parameters
        """
        
        #get a batch
        transitions = mem.sample()
        
        #need to set the Q value of terminal states to 0
        #this mask will be 1 for non-terminal next_states and 0 for terminal next_states
        non_terminal_mask = torch.ByteTensor(list(map(lambda ns: ns is not None, transitions.next_state)))
        
        #this will be 1 for terminal next_states, and 0 for non-terminal next states
        terminal_mask = 1 - non_terminal_mask
        
        #state_batch = (N*C,H,W), where N is batch_size, C is phi_length, H and W are processed obs size
        state_batch = torch.cat(transitions.state).to(device)
        
        #action_batch = (N, 1)
        action_batch = torch.cat(transitions.action).unsqueeze(1).to(device)
        
        #reward_batch = (N, 1)
        reward_batch = torch.cat(transitions.reward).unsqueeze(1).to(device)
        
        #clip reward between +1 and -1
        reward_batch.data.clamp_(-1, 1)
        
        #next_state_batch = (V*C,H,W), where V is non_terminal next_state
        non_terminal_next_state_batch = torch.cat([ns for ns in transitions.next_state if ns is not None]).to(device)
        
        #reshape to (N,C,H,W)
        state_batch = state_batch.view(mem.batch_size, self.phi_length, self.env.size, self.env.size)
        
        #reshape to (V,C,H,W)
        non_terminal_next_state_batch = non_terminal_next_state_batch.view(-1, self.phi_length, self.env.size, self.env.size)
        
        #get predicted Q values from model
        Q_pred = self.model(state_batch)
        
        #get Q values of action taken, shape (N,1)
        Q_vals = Q_pred.gather(1, action_batch)
          
        with torch.no_grad():
            #get Q values from target model  
            target_pred = self.target(non_terminal_next_state_batch)

            #tensor for placing target values
            target_vals = torch.zeros(mem.batch_size, 1).to(device) 
            
            #fill in target values for non_terminal states
            #the terminal states will stay initialized as zeros
            target_vals[non_terminal_mask] = reward_batch[non_terminal_mask] + target_pred.max(1)[0].unsqueeze(1) * self.gamma
            target_vals[terminal_mask] = reward_batch[terminal_mask]
            
        #calculate loss between Q values and target values
        loss = F.smooth_l1_loss(Q_vals, target_vals.detach())
            
        #zero gradients
        self.optimizer.zero_grad()
        
        #calculate gradients 
        loss.backward()
        
        #clamp gradients
        for p in self.model.parameters():
            p.grad.data.clamp_(-1, 1)
            
        #update parameters
        self.optimizer.step()
        
        return loss.item()

# %%
env = Environment(GAME, PROCESSED_SIZE, SEED)
mem = ReplayMemory(CAPACITY, BATCH_SIZE)
model = DQN(N_ACTIONS)
agent = Agent(env, mem, model, PHI_LENGTH, UPDATE_FREQ, EPSILON_START, EPSILON_END, EPSILON_STEPS, GAMMA, TARGET_UPDATE, PRINT_UPDATE)

# %%
s, ns = agent.train()
# Out:
# Episodes: 4, Steps: 5000, Epsilon: 0.85, Avg. Reward per Ep: -20.00
# Episodes: 8, Steps: 10000, Epsilon: 0.72, Avg. Reward per Ep: -20.50
# Episodes: 12, Steps: 15000, Epsilon: 0.61, Avg. Reward per Ep: -20.25
# Episodes: 16, Steps: 20000, Epsilon: 0.52, Avg. Reward per Ep: -19.75
# Episodes: 20, Steps: 25000, Epsilon: 0.44, Avg. Reward per Ep: -20.50
# Episodes: 24, Steps: 30000, Epsilon: 0.37, Avg. Reward per Ep: -20.50
# Episodes: 28, Steps: 35000, Epsilon: 0.32, Avg. Reward per Ep: -20.00
# Episodes: 32, Steps: 40000, Epsilon: 0.27, Avg. Reward per Ep: -20.75
# Episodes: 37, Steps: 45000, Epsilon: 0.23, Avg. Reward per Ep: -20.80
# Episodes: 42, Steps: 50000, Epsilon: 0.20, Avg. Reward per Ep: -20.80
# Episodes: 46, Steps: 55000, Epsilon: 0.17, Avg. Reward per Ep: -20.25
# Episodes: 50, Steps: 60000, Epsilon: 0.14, Avg. Reward per Ep: -20.00
# Episodes: 54, Steps: 65000, Epsilon: 0.12, Avg. Reward per Ep: -20.25
# Episodes: 59, Steps: 70000, Epsilon: 0.11, Avg. Reward per Ep: -20.80
# Episodes: 63, Steps: 75000, Epsilon: 0.09, Avg. Reward per Ep: -21.00
# Episodes: 67, Steps: 80000, Epsilon: 0.08, Avg. Reward per Ep: -20.25
# Episodes: 71, Steps: 85000, Epsilon: 0.07, Avg. Reward per Ep: -20.00
# Episodes: 74, Steps: 90000, Epsilon: 0.06, Avg. Reward per Ep: -18.67
# Episodes: 78, Steps: 95000, Epsilon: 0.05, Avg. Reward per Ep: -19.25
# Episodes: 81, Steps: 100000, Epsilon: 0.05, Avg. Reward per Ep: -18.33
# Episodes: 85, Steps: 105000, Epsilon: 0.04, Avg. Reward per Ep: -20.25
# Episodes: 87, Steps: 110000, Epsilon: 0.04, Avg. Reward per Ep: -20.00
# Episodes: 90, Steps: 115000, Epsilon: 0.03, Avg. Reward per Ep: -17.67
# Episodes: 93, Steps: 120000, Epsilon: 0.03, Avg. Reward per Ep: -18.67
# Episodes: 96, Steps: 125000, Epsilon: 0.03, Avg. Reward per Ep: -18.33
# Episodes: 98, Steps: 130000, Epsilon: 0.02, Avg. Reward per Ep: -17.50
# Episodes: 101, Steps: 135000, Epsilon: 0.02, Avg. Reward per Ep: -17.67
# Episodes: 103, Steps: 140000, Epsilon: 0.02, Avg. Reward per Ep: -19.00
# Episodes: 105, Steps: 145000, Epsilon: 0.02, Avg. Reward per Ep: -17.00
# Episodes: 108, Steps: 150000, Epsilon: 0.02, Avg. Reward per Ep: -17.00
# Episodes: 110, Steps: 155000, Epsilon: 0.02, Avg. Reward per Ep: -18.00
# Episodes: 112, Steps: 160000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 115, Steps: 165000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 117, Steps: 170000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 120, Steps: 175000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 122, Steps: 180000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 123, Steps: 185000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 125, Steps: 190000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 128, Steps: 195000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 130, Steps: 200000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 132, Steps: 205000, Epsilon: 0.01, Avg. Reward per Ep: -18.50
# Episodes: 135, Steps: 210000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 137, Steps: 215000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 139, Steps: 220000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 141, Steps: 225000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 143, Steps: 230000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 145, Steps: 235000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 146, Steps: 240000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 148, Steps: 245000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 149, Steps: 250000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 151, Steps: 255000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 153, Steps: 260000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 155, Steps: 265000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 156, Steps: 270000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 158, Steps: 275000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 160, Steps: 280000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 162, Steps: 285000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 164, Steps: 290000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 165, Steps: 295000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 167, Steps: 300000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 169, Steps: 305000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 171, Steps: 310000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 173, Steps: 315000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 175, Steps: 320000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 176, Steps: 325000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 178, Steps: 330000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 180, Steps: 335000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 182, Steps: 340000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 183, Steps: 345000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 185, Steps: 350000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 187, Steps: 355000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 188, Steps: 360000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 190, Steps: 365000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 192, Steps: 370000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 194, Steps: 375000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 196, Steps: 380000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 198, Steps: 385000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 199, Steps: 390000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 201, Steps: 395000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 202, Steps: 400000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 204, Steps: 405000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 205, Steps: 410000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 207, Steps: 415000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 208, Steps: 420000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 210, Steps: 425000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 212, Steps: 430000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 214, Steps: 435000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 215, Steps: 440000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 217, Steps: 445000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 218, Steps: 450000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 220, Steps: 455000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 222, Steps: 460000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 224, Steps: 465000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 226, Steps: 470000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 227, Steps: 475000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 229, Steps: 480000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 231, Steps: 485000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 233, Steps: 490000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 235, Steps: 495000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 236, Steps: 500000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 238, Steps: 505000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 240, Steps: 510000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 242, Steps: 515000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 244, Steps: 520000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 245, Steps: 525000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 247, Steps: 530000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 249, Steps: 535000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 251, Steps: 540000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 252, Steps: 545000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 254, Steps: 550000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 256, Steps: 555000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 258, Steps: 560000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 260, Steps: 565000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 262, Steps: 570000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 263, Steps: 575000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 265, Steps: 580000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 266, Steps: 585000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 268, Steps: 590000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 270, Steps: 595000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 272, Steps: 600000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 274, Steps: 605000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 276, Steps: 610000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 278, Steps: 615000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 280, Steps: 620000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 282, Steps: 625000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 284, Steps: 630000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 286, Steps: 635000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 288, Steps: 640000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 290, Steps: 645000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 292, Steps: 650000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 293, Steps: 655000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 295, Steps: 660000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 296, Steps: 665000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 298, Steps: 670000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 300, Steps: 675000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 302, Steps: 680000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 304, Steps: 685000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 305, Steps: 690000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 307, Steps: 695000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 309, Steps: 700000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 310, Steps: 705000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 312, Steps: 710000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 315, Steps: 715000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 316, Steps: 720000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 318, Steps: 725000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 320, Steps: 730000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 322, Steps: 735000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 323, Steps: 740000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 325, Steps: 745000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 327, Steps: 750000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 329, Steps: 755000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 331, Steps: 760000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 333, Steps: 765000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 334, Steps: 770000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 336, Steps: 775000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 338, Steps: 780000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 340, Steps: 785000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 342, Steps: 790000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 344, Steps: 795000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 346, Steps: 800000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 348, Steps: 805000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 350, Steps: 810000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 351, Steps: 815000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 353, Steps: 820000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 354, Steps: 825000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 356, Steps: 830000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 358, Steps: 835000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 359, Steps: 840000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 361, Steps: 845000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 363, Steps: 850000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 364, Steps: 855000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 366, Steps: 860000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 367, Steps: 865000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 369, Steps: 870000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 370, Steps: 875000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 372, Steps: 880000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 374, Steps: 885000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 376, Steps: 890000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 377, Steps: 895000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 379, Steps: 900000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 381, Steps: 905000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 383, Steps: 910000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 385, Steps: 915000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 387, Steps: 920000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 388, Steps: 925000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 390, Steps: 930000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 392, Steps: 935000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 394, Steps: 940000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 396, Steps: 945000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 398, Steps: 950000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 399, Steps: 955000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 402, Steps: 960000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 403, Steps: 965000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 405, Steps: 970000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 406, Steps: 975000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 408, Steps: 980000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 410, Steps: 985000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 412, Steps: 990000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 413, Steps: 995000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 416, Steps: 1000000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 418, Steps: 1005000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 420, Steps: 1010000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 421, Steps: 1015000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 424, Steps: 1020000, Epsilon: 0.01, Avg. Reward per Ep: -15.33
# Episodes: 426, Steps: 1025000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 427, Steps: 1030000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 429, Steps: 1035000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 431, Steps: 1040000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 433, Steps: 1045000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 434, Steps: 1050000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 436, Steps: 1055000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 438, Steps: 1060000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 440, Steps: 1065000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 442, Steps: 1070000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 444, Steps: 1075000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 446, Steps: 1080000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 447, Steps: 1085000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 449, Steps: 1090000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 450, Steps: 1095000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 451, Steps: 1100000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 453, Steps: 1105000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 454, Steps: 1110000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 456, Steps: 1115000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 458, Steps: 1120000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 459, Steps: 1125000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 461, Steps: 1130000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 463, Steps: 1135000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 465, Steps: 1140000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 467, Steps: 1145000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 469, Steps: 1150000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 471, Steps: 1155000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 472, Steps: 1160000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 474, Steps: 1165000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 476, Steps: 1170000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 478, Steps: 1175000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 479, Steps: 1180000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 481, Steps: 1185000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 483, Steps: 1190000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 485, Steps: 1195000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 487, Steps: 1200000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 488, Steps: 1205000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 490, Steps: 1210000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 492, Steps: 1215000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 494, Steps: 1220000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 495, Steps: 1225000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 497, Steps: 1230000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 498, Steps: 1235000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 500, Steps: 1240000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 502, Steps: 1245000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 503, Steps: 1250000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 505, Steps: 1255000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 507, Steps: 1260000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 508, Steps: 1265000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 510, Steps: 1270000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 511, Steps: 1275000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 513, Steps: 1280000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 515, Steps: 1285000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 517, Steps: 1290000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 519, Steps: 1295000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 521, Steps: 1300000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 523, Steps: 1305000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 525, Steps: 1310000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 527, Steps: 1315000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 528, Steps: 1320000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 530, Steps: 1325000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 531, Steps: 1330000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 533, Steps: 1335000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 535, Steps: 1340000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 537, Steps: 1345000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 539, Steps: 1350000, Epsilon: 0.01, Avg. Reward per Ep: -19.50
# Episodes: 541, Steps: 1355000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 543, Steps: 1360000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 544, Steps: 1365000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 546, Steps: 1370000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 548, Steps: 1375000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 550, Steps: 1380000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 552, Steps: 1385000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 553, Steps: 1390000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 555, Steps: 1395000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 558, Steps: 1400000, Epsilon: 0.01, Avg. Reward per Ep: -17.67
# Episodes: 560, Steps: 1405000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 561, Steps: 1410000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 563, Steps: 1415000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 565, Steps: 1420000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 567, Steps: 1425000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 569, Steps: 1430000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 572, Steps: 1435000, Epsilon: 0.01, Avg. Reward per Ep: -17.67
# Episodes: 573, Steps: 1440000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 575, Steps: 1445000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 577, Steps: 1450000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 579, Steps: 1455000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 581, Steps: 1460000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 583, Steps: 1465000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 585, Steps: 1470000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 586, Steps: 1475000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 588, Steps: 1480000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 590, Steps: 1485000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 592, Steps: 1490000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 593, Steps: 1495000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 595, Steps: 1500000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 597, Steps: 1505000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 599, Steps: 1510000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 600, Steps: 1515000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 602, Steps: 1520000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 604, Steps: 1525000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 606, Steps: 1530000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 608, Steps: 1535000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 610, Steps: 1540000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 612, Steps: 1545000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 614, Steps: 1550000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 616, Steps: 1555000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 617, Steps: 1560000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 619, Steps: 1565000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 621, Steps: 1570000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 623, Steps: 1575000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 624, Steps: 1580000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 627, Steps: 1585000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 629, Steps: 1590000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 630, Steps: 1595000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 632, Steps: 1600000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 633, Steps: 1605000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 635, Steps: 1610000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 637, Steps: 1615000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 639, Steps: 1620000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 641, Steps: 1625000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 642, Steps: 1630000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 644, Steps: 1635000, Epsilon: 0.01, Avg. Reward per Ep: -8.50
# Episodes: 645, Steps: 1640000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 648, Steps: 1645000, Epsilon: 0.01, Avg. Reward per Ep: -15.33
# Episodes: 649, Steps: 1650000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 651, Steps: 1655000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 653, Steps: 1660000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 655, Steps: 1665000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 657, Steps: 1670000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 659, Steps: 1675000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 661, Steps: 1680000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 663, Steps: 1685000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 664, Steps: 1690000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 666, Steps: 1695000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 668, Steps: 1700000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 670, Steps: 1705000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 672, Steps: 1710000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 674, Steps: 1715000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 676, Steps: 1720000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 678, Steps: 1725000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 680, Steps: 1730000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 682, Steps: 1735000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 684, Steps: 1740000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 686, Steps: 1745000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 687, Steps: 1750000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 689, Steps: 1755000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 691, Steps: 1760000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 692, Steps: 1765000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 694, Steps: 1770000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 696, Steps: 1775000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 697, Steps: 1780000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 699, Steps: 1785000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 701, Steps: 1790000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 702, Steps: 1795000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 704, Steps: 1800000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 706, Steps: 1805000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 707, Steps: 1810000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 709, Steps: 1815000, Epsilon: 0.01, Avg. Reward per Ep: -8.50
# Episodes: 710, Steps: 1820000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 712, Steps: 1825000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 714, Steps: 1830000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 716, Steps: 1835000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 717, Steps: 1840000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 719, Steps: 1845000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 721, Steps: 1850000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 723, Steps: 1855000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 725, Steps: 1860000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 727, Steps: 1865000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 729, Steps: 1870000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 731, Steps: 1875000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 733, Steps: 1880000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 735, Steps: 1885000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 737, Steps: 1890000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 738, Steps: 1895000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 740, Steps: 1900000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 742, Steps: 1905000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 744, Steps: 1910000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 746, Steps: 1915000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 748, Steps: 1920000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 750, Steps: 1925000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 752, Steps: 1930000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 753, Steps: 1935000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 755, Steps: 1940000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 757, Steps: 1945000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 758, Steps: 1950000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 760, Steps: 1955000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 762, Steps: 1960000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 764, Steps: 1965000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 765, Steps: 1970000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 767, Steps: 1975000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 769, Steps: 1980000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 771, Steps: 1985000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 773, Steps: 1990000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 775, Steps: 1995000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 777, Steps: 2000000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 779, Steps: 2005000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 781, Steps: 2010000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 783, Steps: 2015000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 785, Steps: 2020000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 787, Steps: 2025000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 788, Steps: 2030000, Epsilon: 0.01, Avg. Reward per Ep: -5.00
# Episodes: 790, Steps: 2035000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 792, Steps: 2040000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 793, Steps: 2045000, Epsilon: 0.01, Avg. Reward per Ep: -6.00
# Episodes: 795, Steps: 2050000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 797, Steps: 2055000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 799, Steps: 2060000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 801, Steps: 2065000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 803, Steps: 2070000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 804, Steps: 2075000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 807, Steps: 2080000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 809, Steps: 2085000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 811, Steps: 2090000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 813, Steps: 2095000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 815, Steps: 2100000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 817, Steps: 2105000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 819, Steps: 2110000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 820, Steps: 2115000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 823, Steps: 2120000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 824, Steps: 2125000, Epsilon: 0.01, Avg. Reward per Ep: -7.00
# Episodes: 826, Steps: 2130000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 828, Steps: 2135000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 830, Steps: 2140000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 832, Steps: 2145000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 835, Steps: 2150000, Epsilon: 0.01, Avg. Reward per Ep: -15.67
# Episodes: 837, Steps: 2155000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 839, Steps: 2160000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 840, Steps: 2165000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 842, Steps: 2170000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 844, Steps: 2175000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 845, Steps: 2180000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 847, Steps: 2185000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 849, Steps: 2190000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 850, Steps: 2195000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 852, Steps: 2200000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 854, Steps: 2205000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 855, Steps: 2210000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 857, Steps: 2215000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 859, Steps: 2220000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 861, Steps: 2225000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 863, Steps: 2230000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 865, Steps: 2235000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 867, Steps: 2240000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 868, Steps: 2245000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 870, Steps: 2250000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 872, Steps: 2255000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 873, Steps: 2260000, Epsilon: 0.01, Avg. Reward per Ep: -7.00
# Episodes: 875, Steps: 2265000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 877, Steps: 2270000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 878, Steps: 2275000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 880, Steps: 2280000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 881, Steps: 2285000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 883, Steps: 2290000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 885, Steps: 2295000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 887, Steps: 2300000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 888, Steps: 2305000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 890, Steps: 2310000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 892, Steps: 2315000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 893, Steps: 2320000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 895, Steps: 2325000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 897, Steps: 2330000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 899, Steps: 2335000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 900, Steps: 2340000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 902, Steps: 2345000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 903, Steps: 2350000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 905, Steps: 2355000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 907, Steps: 2360000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 909, Steps: 2365000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 911, Steps: 2370000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 913, Steps: 2375000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 914, Steps: 2380000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 916, Steps: 2385000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 918, Steps: 2390000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 920, Steps: 2395000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 922, Steps: 2400000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 923, Steps: 2405000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 925, Steps: 2410000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 926, Steps: 2415000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 927, Steps: 2420000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 929, Steps: 2425000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 931, Steps: 2430000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 932, Steps: 2435000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 934, Steps: 2440000, Epsilon: 0.01, Avg. Reward per Ep: -7.50
# Episodes: 935, Steps: 2445000, Epsilon: 0.01, Avg. Reward per Ep: -7.00
# Episodes: 936, Steps: 2450000, Epsilon: 0.01, Avg. Reward per Ep: -6.00
# Episodes: 938, Steps: 2455000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 939, Steps: 2460000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 941, Steps: 2465000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 942, Steps: 2470000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 944, Steps: 2475000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 946, Steps: 2480000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 948, Steps: 2485000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 950, Steps: 2490000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 951, Steps: 2495000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 953, Steps: 2500000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 955, Steps: 2505000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 956, Steps: 2510000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 958, Steps: 2515000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 959, Steps: 2520000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 961, Steps: 2525000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 962, Steps: 2530000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 964, Steps: 2535000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 965, Steps: 2540000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 967, Steps: 2545000, Epsilon: 0.01, Avg. Reward per Ep: -9.50
# Episodes: 969, Steps: 2550000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 970, Steps: 2555000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 972, Steps: 2560000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 973, Steps: 2565000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 976, Steps: 2570000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 977, Steps: 2575000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 979, Steps: 2580000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 981, Steps: 2585000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 983, Steps: 2590000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 985, Steps: 2595000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 987, Steps: 2600000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 989, Steps: 2605000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 991, Steps: 2610000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 993, Steps: 2615000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 994, Steps: 2620000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 996, Steps: 2625000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 998, Steps: 2630000, Epsilon: 0.01, Avg. Reward per Ep: -7.50
# Episodes: 999, Steps: 2635000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1001, Steps: 2640000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1002, Steps: 2645000, Epsilon: 0.01, Avg. Reward per Ep: -4.00
# Episodes: 1004, Steps: 2650000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1006, Steps: 2655000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1008, Steps: 2660000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1009, Steps: 2665000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1011, Steps: 2670000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1013, Steps: 2675000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1014, Steps: 2680000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1016, Steps: 2685000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1018, Steps: 2690000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1020, Steps: 2695000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1022, Steps: 2700000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1024, Steps: 2705000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 1026, Steps: 2710000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1028, Steps: 2715000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1030, Steps: 2720000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1032, Steps: 2725000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1034, Steps: 2730000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1035, Steps: 2735000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 1037, Steps: 2740000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1039, Steps: 2745000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1040, Steps: 2750000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1042, Steps: 2755000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1044, Steps: 2760000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1045, Steps: 2765000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1047, Steps: 2770000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 1049, Steps: 2775000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1050, Steps: 2780000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1052, Steps: 2785000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1054, Steps: 2790000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1056, Steps: 2795000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1058, Steps: 2800000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1059, Steps: 2805000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1061, Steps: 2810000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1063, Steps: 2815000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1065, Steps: 2820000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1067, Steps: 2825000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1069, Steps: 2830000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1071, Steps: 2835000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1073, Steps: 2840000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1074, Steps: 2845000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1076, Steps: 2850000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1078, Steps: 2855000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1079, Steps: 2860000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1081, Steps: 2865000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1083, Steps: 2870000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 1086, Steps: 2875000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1088, Steps: 2880000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 1090, Steps: 2885000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1092, Steps: 2890000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1094, Steps: 2895000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 1096, Steps: 2900000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1098, Steps: 2905000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1100, Steps: 2910000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1102, Steps: 2915000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1104, Steps: 2920000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1106, Steps: 2925000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1109, Steps: 2930000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1110, Steps: 2935000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1112, Steps: 2940000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 1114, Steps: 2945000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1115, Steps: 2950000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1117, Steps: 2955000, Epsilon: 0.01, Avg. Reward per Ep: -6.00
# Episodes: 1118, Steps: 2960000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1120, Steps: 2965000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1121, Steps: 2970000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1123, Steps: 2975000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1125, Steps: 2980000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1126, Steps: 2985000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1128, Steps: 2990000, Epsilon: 0.01, Avg. Reward per Ep: -7.00
# Episodes: 1129, Steps: 2995000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1131, Steps: 3000000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1133, Steps: 3005000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1134, Steps: 3010000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1136, Steps: 3015000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1137, Steps: 3020000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1139, Steps: 3025000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1140, Steps: 3030000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1142, Steps: 3035000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 1143, Steps: 3040000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1145, Steps: 3045000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1146, Steps: 3050000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1148, Steps: 3055000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 1150, Steps: 3060000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1152, Steps: 3065000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1153, Steps: 3070000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1155, Steps: 3075000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1157, Steps: 3080000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1158, Steps: 3085000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1160, Steps: 3090000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1161, Steps: 3095000, Epsilon: 0.01, Avg. Reward per Ep: -8.00
# Episodes: 1163, Steps: 3100000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1165, Steps: 3105000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1166, Steps: 3110000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1168, Steps: 3115000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1169, Steps: 3120000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1171, Steps: 3125000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1172, Steps: 3130000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1174, Steps: 3135000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1175, Steps: 3140000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1177, Steps: 3145000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1179, Steps: 3150000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1180, Steps: 3155000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1182, Steps: 3160000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1183, Steps: 3165000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1186, Steps: 3170000, Epsilon: 0.01, Avg. Reward per Ep: -16.67
# Episodes: 1187, Steps: 3175000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1189, Steps: 3180000, Epsilon: 0.01, Avg. Reward per Ep: -8.50
# Episodes: 1191, Steps: 3185000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1192, Steps: 3190000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1194, Steps: 3195000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1195, Steps: 3200000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1196, Steps: 3205000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1198, Steps: 3210000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 1199, Steps: 3215000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 1201, Steps: 3220000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1203, Steps: 3225000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1205, Steps: 3230000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1206, Steps: 3235000, Epsilon: 0.01, Avg. Reward per Ep: -5.00
# Episodes: 1207, Steps: 3240000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1209, Steps: 3245000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1211, Steps: 3250000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1213, Steps: 3255000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1215, Steps: 3260000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1216, Steps: 3265000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1218, Steps: 3270000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1220, Steps: 3275000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1222, Steps: 3280000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1223, Steps: 3285000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1225, Steps: 3290000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1227, Steps: 3295000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 1229, Steps: 3300000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 1231, Steps: 3305000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1233, Steps: 3310000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 1235, Steps: 3315000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1236, Steps: 3320000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1238, Steps: 3325000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1241, Steps: 3330000, Epsilon: 0.01, Avg. Reward per Ep: -18.67
# Episodes: 1243, Steps: 3335000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 1244, Steps: 3340000, Epsilon: 0.01, Avg. Reward per Ep: -9.00
# Episodes: 1247, Steps: 3345000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1249, Steps: 3350000, Epsilon: 0.01, Avg. Reward per Ep: -17.50
# Episodes: 1252, Steps: 3355000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1254, Steps: 3360000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1256, Steps: 3365000, Epsilon: 0.01, Avg. Reward per Ep: -18.00
# Episodes: 1258, Steps: 3370000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1260, Steps: 3375000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1261, Steps: 3380000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1263, Steps: 3385000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1265, Steps: 3390000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1267, Steps: 3395000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1269, Steps: 3400000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1271, Steps: 3405000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1273, Steps: 3410000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1275, Steps: 3415000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1277, Steps: 3420000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1279, Steps: 3425000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1282, Steps: 3430000, Epsilon: 0.01, Avg. Reward per Ep: -15.67
# Episodes: 1284, Steps: 3435000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1286, Steps: 3440000, Epsilon: 0.01, Avg. Reward per Ep: -17.00
# Episodes: 1288, Steps: 3445000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1290, Steps: 3450000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1292, Steps: 3455000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1294, Steps: 3460000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1296, Steps: 3465000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1298, Steps: 3470000, Epsilon: 0.01, Avg. Reward per Ep: -16.50
# Episodes: 1300, Steps: 3475000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1302, Steps: 3480000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1304, Steps: 3485000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1306, Steps: 3490000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1308, Steps: 3495000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1310, Steps: 3500000, Epsilon: 0.01, Avg. Reward per Ep: -15.50
# Episodes: 1311, Steps: 3505000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1313, Steps: 3510000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1314, Steps: 3515000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1316, Steps: 3520000, Epsilon: 0.01, Avg. Reward per Ep: -13.00
# Episodes: 1318, Steps: 3525000, Epsilon: 0.01, Avg. Reward per Ep: -12.50
# Episodes: 1319, Steps: 3530000, Epsilon: 0.01, Avg. Reward per Ep: -10.00
# Episodes: 1321, Steps: 3535000, Epsilon: 0.01, Avg. Reward per Ep: -10.50
# Episodes: 1323, Steps: 3540000, Epsilon: 0.01, Avg. Reward per Ep: -12.00
# Episodes: 1325, Steps: 3545000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1327, Steps: 3550000, Epsilon: 0.01, Avg. Reward per Ep: -13.50
# Episodes: 1328, Steps: 3555000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# Episodes: 1330, Steps: 3560000, Epsilon: 0.01, Avg. Reward per Ep: -11.50
# Episodes: 1332, Steps: 3565000, Epsilon: 0.01, Avg. Reward per Ep: -15.00
# Episodes: 1335, Steps: 3570000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1337, Steps: 3575000, Epsilon: 0.01, Avg. Reward per Ep: -14.00
# Episodes: 1339, Steps: 3580000, Epsilon: 0.01, Avg. Reward per Ep: -14.50
# Episodes: 1341, Steps: 3585000, Epsilon: 0.01, Avg. Reward per Ep: -16.00
# Episodes: 1344, Steps: 3590000, Epsilon: 0.01, Avg. Reward per Ep: -15.67
# Episodes: 1345, Steps: 3595000, Epsilon: 0.01, Avg. Reward per Ep: -11.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-49f0488627db> in <module>()
# ----> 1 s, ns = agent.train()
#
# <ipython-input-17-4beff70ffd78> in train(self)
#     163                 #update model parameters
#     164                 if mem.is_available() and self.steps % self.update_freq == 0 and self.steps > 10_000:
# --> 165                     loss = self.optimize()
#     166
#     167                 if self.steps % (self.target_update*self.update_freq) == 0 and self.steps > 10_000:
#
# <ipython-input-17-4beff70ffd78> in optimize(self)
#     201
#     202         #reward_batch = (N, 1)
# --> 203         reward_batch = torch.cat(transitions.reward).unsqueeze(1).to(device)
#     204
#     205         #clip reward between +1 and -1
#
# KeyboardInterrupt:

# %% [markdown]
# 1 - DQN IS USING NO-WRAPPERS AND PARAMETERS FROM THE UNTITLED NOTEBOOK (I.E EPSILON)
# ALSO HAS THE FIXED REWARD[TERMINAL_MASK] THING, TARGET SET TO TRAIN (IMPLICITLY)
#
# 1 - DQN-Copy2 IS USING WRAPPERS, PARAMETERS FROM NOTEBOOK, FIXED REWARD[TERMINAL_MASK] AND EXPLICITLY SETS TARGET TO TRAIN
# I THINK I CAN REMOVE THE EXPLICIT TRAIN
#
# 2 - DQN-Copy1 SAME AS ABOVE BUT WITH TARGET SET TO EVAL **THIS SHOULD BE CORRECT**
# ALSO SHOULD GIVE SAME RESULTS AS Copy2 DUE TO SEEDS BEING SET. EVAL SHOULD BE RIGHT BECAUSE WHAT ABOUT IF YOU USED BATCH NORM. **RESULTS ARE DIFFERENT**, SOMEWHERE THE SEED IS NOT BEING SET PROPERLY.
#
# 3 - DQN-Copy3 is a copy of copy1, using it to test determinism, i.e. if the seeds are all set correctly (which I believe they are) then results should be exact same as copy1.
#
# **TEST RANDOM SEED THING TOMORROW BY RUNNING RESULTS FOR DQN-Copy1 and Copy2 AND SEEING IF THEY GIVE THE SAME AS ONES TRAINED 2NITE**
