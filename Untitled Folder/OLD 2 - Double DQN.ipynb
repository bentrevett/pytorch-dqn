# %% [markdown]
# - http://coach.nervanasys.com/algorithms/value_optimization/double_dqn/index.html
# - https://medium.com/@awjuliani/simple-reinforcement-learning-with-tensorflow-part-4-deep-q-networks-and-beyond-8438a3e2b8df
# - https://jaromiru.com/2016/11/07/lets-make-a-dqn-double-learning-and-prioritized-experience-replay/

# %%
import matplotlib.pyplot as plt
import gym
import cv2
import random
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
from collections import namedtuple
import copy

# %%
SEED = 1234
CAPACITY = 10_000
BATCH_SIZE = 32
PROCESSED_SIZE = 84
GAME = 'Pong-v0'
N_ACTIONS = gym.make(GAME).action_space.n
PHI_LENGTH = 4
UPDATE_FREQ = 1
EPSILON_START = 1.0
EPSILON_END = 0.1
EPSILON_STEPS = 1_000_000
GAMMA = 0.99
TARGET_UPDATE = 1000
PRINT_UPDATE = 5_000

# %%
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class ReplayMemory:
    def __init__(self, capacity, batch_size):
        """
        Replay memory that holds examples in the form of (s, a, r, s')
        
        args:
            capacity (int): the size of the memory
            batch_size (int): size of batches used for training model
        """
        
        self.batch_size = batch_size
        self.capacity = capacity
        self.memory = deque(maxlen=self.capacity)
        self.Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state'))
        self._available = False

    def put(self, state, action, reward, next_state):
        """
        Places an (s, a, r, s') example in the memory
        
        args:
            state (np.array): 
            action (list[int]):
            reward (list[int]):
            next_state (np.array or None):
        """
        
        state = torch.FloatTensor(state)
        action = torch.LongTensor([action])
        reward = torch.FloatTensor([reward])
        if next_state is not None:
            next_state = torch.FloatTensor(next_state)
        transition = self.Transition(state=state, action=action, reward=reward, next_state=next_state)
        self.memory.append(transition)

    def sample(self):
        """
        Gets a random sample of n = batch_size examples from the memory
            
        returns:
            Transitions (namedtuple): a tuple of (s, a, r, s')
        """
        
        transitions = random.sample(self.memory, self.batch_size)
        return self.Transition(*(zip(*transitions)))

    def size(self):
        """
        Returns the length of the memory
        
        returns:
            length (int): number of examples in the memory
        """
        return len(self.memory)

    def is_available(self):
        """
        Returns True if we have enough examples within the memory
        
        returns:
            available (bool): True if we have at least n = batch_size examples in the memory
        """
        if self._available:
            return True

        if len(self.memory) > self.batch_size:
            self._available = True
        return self._available

# %%
class Environment:
    def __init__(self, game, size, seed):
        """
        A class that has helpful wrappers around the Gym environment
        
        game (string): name of Atari game, i.e. Breakout-v0
        size (int): height and width of observation after preprocessing
        seed (int): random seed
        """
        
        self.size = size
        
        #init game
        self.game = gym.make(game)
        
        #set random seed for determinism
        self.game.seed(seed)
        
    def process(self, obs):
        """
        Process an observation (i.e. convert to grayscale, resize and normalize)
        
        args:
            obs (np.array): observation from gym of game screen, should be (height, width, channels)
        
        returns:
            output (np.array): (self.size, self.size) array with all values <= 1
        """
        
        assert len(obs.shape) == 3 #make sure image is correct shape
        
        gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY) #convert to grayscale
        output = cv2.resize(gray, (self.size, self.size)) #resize
        output = output.astype(np.float32, copy=False) #convert to float32
        output /= 255.0 #normalize values between [0, 1]
                     
        assert (output <= 1.0).all() 
                        
        return output
    
    def get_obs(self):
        """
        Gets a processed observation
        
        returns:
            obs (np.array): (self.size, self.size) array with all values <= 1
        """
        
        obs = self.game.render('rgb_array')
        obs = self.process(obs)
        return obs
    
    def init(self):
        """
        Reset the environment and return the initial state (unprocessed)
        
        returns:
            obs (np.array): observation from gym of game screen, should be (height, width, channels)
        """
        obs = self.game.reset()
        return obs
    
    def reset(self):
        """
        Reset the environment and return the initial state (processed)
        
        returns:
            output (np.array): (self.size, self.size) array with all values <= 1
        """
        obs = self.game.reset()
        output = self.process(obs)
        return output

# %%
class DQN(nn.Module):

    def __init__(self, n_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(7*7*64, 512)
        self.fc2 = nn.Linear(512, n_actions) #actions from from env.action_space.n

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc1(x.view(x.size(0), -1))) #flattens the (N, C, H, W) to (N, C*H*W)
        return self.fc2(x)

# %%
class Agent:
    def __init__(self, env, mem, model, phi_length, update_freq, e_start, e_end, e_steps, gamma, target_update, print_update):
        """
        An agent class that handles training the model

        args:
            mem (ReplayMemory): ReplayMemory object
            env (Environment): Environment object
            model (nn.Module): PyTorch model
            phi_length (int): number of observations to stack to make a state
            frame_skip (int): we only use every n = frame_skip observations to make a state
            e_start (int): initial value of epsilon
            e_end (int): minimum value of epsilon
            e_steps (int): number of steps for epsilon to go from e_start to e_end
            gamma (float): decay rate of rewards
            target_update (int): after how many steps (frames) to update target model
            print_update (int): after how many steps (frames) to print summary of performance
            
        """
        self.env = env
        self.mem = mem
        self.model = model
        self.phi_length = phi_length
        self.update_freq = update_freq
        self.e_start = e_start
        self.e_end = e_end
        self.e_steps = e_steps
        self.gamma = gamma
        self.target_update = target_update
        self.print_update = print_update
        
        self.steps = 0 #number of steps taken
        self.episodes = 0 #number of episodes
        self.obs_buffer = deque(maxlen=phi_length) #for holding observations to be turned into states
        
        #put model on gpu if available
        self.model = model.to(device)
        
        #create target model
        #TODO: this may need to be a copy.deepcopy or load state dict
        self.target = copy.deepcopy(self.model)
    
        #create optimizer
        #trying params from: https://github.com/hengyuan-hu/rainbow
        #self.optimizer = optim.Adam(self.model.parameters(), lr=6.25e-5, eps=1.5e-4)
        #from dqn paper
        self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025, alpha=0.95, momentum=0.95)
        
    def get_epsilon(self):
        """
        Calculates the value of epsilon from the current number of frames
        
        returns:
            epsilon (int): the probability of doing a random action
        """
        epsilon = self.e_end + (self.e_start - self.e_end) * math.exp(-1. * self.steps / self.e_steps)
        return epsilon
        
    def get_action(self, state):
        """
        Selects action to perform, with probability = epsilon chooses a random action,
        else chooses the best predicted action of the model
        
        args:
            state (np.array): input state to the model
            
        returns:
            action (int): the index of the action 
        """
    
        #get value of epsilon
        epsilon = self.get_epsilon()
        
        #with probablity of epsilon, pick a random action
        if random.random() < epsilon:
            action = self.env.game.action_space.sample()
        
        else:
            #with probability of (1 - epsilon) pick predicted value
            with torch.no_grad():
                state = torch.FloatTensor(state).unsqueeze(0).to(device) #convert to tensor, reshape and add to gpu
                Qsa = self.model(state) #pass state through model to get Qa
                action = Qsa.max(1)[1].item() #action is max Qa value
                
        #make sure the value is an integer
        assert isinstance(action, int)
            
        return action
    
    def get_initial_state(self):
        """
        Get the initial state to the model, a stack of processed observations
        
        returns:
            state (np.array): a stack of n = phi_length processed observations
        """
        
        _ = self.env.reset() #reset environment
        obs = self.env.get_obs() #get a processed observation
        state = np.stack([obs for _ in range(self.phi_length)], axis=0) #stack n = phi_length times to make a state
        
        #also fill the 
        for _ in range(self.phi_length):
            self.obs_buffer.append(obs)
        
        return state
        
    def get_state(self):
        """
        Get a stack from the observation buffer
        
        returns:
            state (np.array): a stack of n = phi_length processed observations
        """
        
        state = np.array(self.obs_buffer)
        
        return state
        
    def train(self):
        
        training_done = False
        reward_per_episode = []
        rewards_all_episodes = []
        
        while not training_done:
            
            episode_done = False
            episode_reward = 0
            episode_steps = 0
            
            #get initial state
            state = self.get_initial_state()
            
            while not episode_done:
                                
                #get action
                action = self.get_action(state)
                               
                #apply action while skipping frames
                observation, reward, episode_done, info = self.env.game.step(action)

                #sum rewards
                episode_reward += reward
                    
                #append processed observation to a buffer of observations
                self.obs_buffer.append(self.env.get_obs())
                        
                #get the next state from the observation buffer
                next_state = self.get_state()
                
                #add to memory, for terminal states, set next_state to None
                if episode_done:
                    mem.put(state, action, reward, None)
                else:
                    mem.put(state, action, reward, next_state)
                    
                #make new state the old next_state
                state = next_state
                                
                #update model parameters
                if mem.is_available() and self.steps % self.update_freq == 0:
                    loss = self.optimize()
    
                #increase number of steps
                self.steps += 1
                episode_steps += 1 
            
                if self.steps % (self.target_update * self.update_freq) == 0:
                    self.target.load_state_dict(self.model.state_dict())
            
                if self.steps % self.print_update == 0:
                    avg_reward_per_episode = np.mean(reward_per_episode)
                    #rewards_all_episodes.extend(reward_per_episode)
                    reward_per_episode = []
                    print(f'Episodes: {self.episodes}, Steps: {self.steps}, Epsilon: {self.get_epsilon():.2f}, Avg. Reward per Ep: {avg_reward_per_episode:.2f}')

            #increase number of episodes
            self.episodes += 1
            reward_per_episode.append(episode_reward)
            
    def optimize(self):
        """
        Update model parameters
        """
        
        #get a batch
        transitions = mem.sample()
        
        #need to set the Q value of terminal states to 0
        #this mask will be 1 for non-terminal next_states and 0 for terminal next_states
        non_terminal_mask = torch.ByteTensor(list(map(lambda ns: ns is not None, transitions.next_state)))
        
        #this will be 1 for terminal next_states, and 0 for non-terminal next states
        terminal_mask = 1 - non_terminal_mask
        
        #state_batch = (N*C,H,W), where N is batch_size, C is phi_length, H and W are processed obs size
        state_batch = torch.cat(transitions.state).to(device)
        
        #action_batch = (N, 1)
        action_batch = torch.cat(transitions.action).unsqueeze(1).to(device)
        
        #reward_batch = (N, 1)
        reward_batch = torch.cat(transitions.reward).unsqueeze(1).to(device)
        
        #clip reward between +1 and -1
        reward_batch.data.clamp_(-1, 1)
        
        #next_state_batch = (V*C,H,W), where V is non_terminal next_state
        non_terminal_next_state_batch = torch.cat([ns for ns in transitions.next_state if ns is not None]).to(device)
        
        #reshape to (N,C,H,W)
        state_batch = state_batch.view(mem.batch_size, self.phi_length, self.env.size, self.env.size)
        
        #reshape to (V,C,H,W)
        non_terminal_next_state_batch = non_terminal_next_state_batch.view(-1, self.phi_length, self.env.size, self.env.size)
        
        #get predicted Q values from model
        Q_pred = self.model(state_batch)
        
        #get Q values of action taken, shape (N,1)
        Q_vals = Q_pred.gather(1, action_batch)
          
        """
        in double dqn, get q values from model and target
        """
        #get Q values from target model  
        model_pred = self.model(non_terminal_next_state_batch)
        target_pred = self.target(non_terminal_next_state_batch) 
            
        """
        then get the actions from the model predicted Q values, not the target
        """
        target_actions = model_pred.max(dim=1)[1].view(-1, 1)
        
        """
        then use these actions to get Q values from the target network
        """
        target_Q = target_pred.gather(1, target_actions) 
            
        #tensor for placing target values
        target_vals = torch.zeros(mem.batch_size, 1).to(device) 
            
        """
        don't forget to update this line
        """    
        #fill in target values for non_terminal states
        #the terminal states will stay initialized as zeros
        target_vals[non_terminal_mask] = reward_batch[non_terminal_mask] + target_Q * self.gamma
            
        #calculate loss between Q values and target values
        loss = F.smooth_l1_loss(Q_vals, target_vals.detach())
            
        #zero gradients
        self.optimizer.zero_grad()
        
        #calculate gradients 
        loss.backward()
        
        #clamp gradients
        for p in self.model.parameters():
            p.grad.data.clamp_(-1, 1)
            
        #update parameters
        self.optimizer.step()
        
        return loss.item()
# Out:
#   File "<ipython-input-11-bdf299954458>", line 97
#     """
#     ^
# IndentationError: unexpected indent

# %%
env = Environment(GAME, PROCESSED_SIZE, SEED)
mem = ReplayMemory(CAPACITY, BATCH_SIZE)
model = DQN(N_ACTIONS)
agent = Agent(env, mem, model, PHI_LENGTH, UPDATE_FREQ, EPSILON_START, EPSILON_END, EPSILON_STEPS, GAMMA, TARGET_UPDATE, PRINT_UPDATE)

# %%
agent.train()
# Out:
# Episodes: 3, Steps: 5000, Epsilon: 1.00, Avg. Reward per Ep: -19.33
# Episodes: 7, Steps: 10000, Epsilon: 0.99, Avg. Reward per Ep: -20.00
# Episodes: 11, Steps: 15000, Epsilon: 0.99, Avg. Reward per Ep: -20.00
# Episodes: 15, Steps: 20000, Epsilon: 0.98, Avg. Reward per Ep: -19.75
# Episodes: 19, Steps: 25000, Epsilon: 0.98, Avg. Reward per Ep: -20.25
# Episodes: 24, Steps: 30000, Epsilon: 0.97, Avg. Reward per Ep: -20.80
# Episodes: 27, Steps: 35000, Epsilon: 0.97, Avg. Reward per Ep: -20.00
# Episodes: 32, Steps: 40000, Epsilon: 0.96, Avg. Reward per Ep: -21.00
# Episodes: 36, Steps: 45000, Epsilon: 0.96, Avg. Reward per Ep: -20.00
# Episodes: 40, Steps: 50000, Epsilon: 0.96, Avg. Reward per Ep: -20.50
# Episodes: 44, Steps: 55000, Epsilon: 0.95, Avg. Reward per Ep: -20.50
# Episodes: 48, Steps: 60000, Epsilon: 0.95, Avg. Reward per Ep: -20.50
# Episodes: 52, Steps: 65000, Epsilon: 0.94, Avg. Reward per Ep: -19.00
# Episodes: 56, Steps: 70000, Epsilon: 0.94, Avg. Reward per Ep: -21.00
# Episodes: 60, Steps: 75000, Epsilon: 0.93, Avg. Reward per Ep: -19.50
# Episodes: 64, Steps: 80000, Epsilon: 0.93, Avg. Reward per Ep: -19.75
# Episodes: 68, Steps: 85000, Epsilon: 0.93, Avg. Reward per Ep: -19.75
# Episodes: 72, Steps: 90000, Epsilon: 0.92, Avg. Reward per Ep: -20.25
# Episodes: 76, Steps: 95000, Epsilon: 0.92, Avg. Reward per Ep: -20.25
# Episodes: 81, Steps: 100000, Epsilon: 0.91, Avg. Reward per Ep: -21.00
# Episodes: 85, Steps: 105000, Epsilon: 0.91, Avg. Reward per Ep: -20.25
# Episodes: 89, Steps: 110000, Epsilon: 0.91, Avg. Reward per Ep: -20.00
# Episodes: 92, Steps: 115000, Epsilon: 0.90, Avg. Reward per Ep: -21.00
# Episodes: 96, Steps: 120000, Epsilon: 0.90, Avg. Reward per Ep: -20.25
# Episodes: 100, Steps: 125000, Epsilon: 0.89, Avg. Reward per Ep: -20.75
# Episodes: 104, Steps: 130000, Epsilon: 0.89, Avg. Reward per Ep: -19.25
# Episodes: 108, Steps: 135000, Epsilon: 0.89, Avg. Reward per Ep: -20.50
# Episodes: 112, Steps: 140000, Epsilon: 0.88, Avg. Reward per Ep: -19.75
# Episodes: 116, Steps: 145000, Epsilon: 0.88, Avg. Reward per Ep: -20.50
# Episodes: 120, Steps: 150000, Epsilon: 0.87, Avg. Reward per Ep: -20.00
# Episodes: 123, Steps: 155000, Epsilon: 0.87, Avg. Reward per Ep: -20.00
# Episodes: 127, Steps: 160000, Epsilon: 0.87, Avg. Reward per Ep: -20.75
# Episodes: 131, Steps: 165000, Epsilon: 0.86, Avg. Reward per Ep: -19.75
# Episodes: 135, Steps: 170000, Epsilon: 0.86, Avg. Reward per Ep: -19.50
# Episodes: 138, Steps: 175000, Epsilon: 0.86, Avg. Reward per Ep: -20.33
# Episodes: 142, Steps: 180000, Epsilon: 0.85, Avg. Reward per Ep: -20.00
# Episodes: 146, Steps: 185000, Epsilon: 0.85, Avg. Reward per Ep: -20.25
# Episodes: 150, Steps: 190000, Epsilon: 0.84, Avg. Reward per Ep: -20.00
# Episodes: 154, Steps: 195000, Epsilon: 0.84, Avg. Reward per Ep: -20.00
# Episodes: 158, Steps: 200000, Epsilon: 0.84, Avg. Reward per Ep: -19.25
# Episodes: 162, Steps: 205000, Epsilon: 0.83, Avg. Reward per Ep: -20.25
# Episodes: 166, Steps: 210000, Epsilon: 0.83, Avg. Reward per Ep: -20.50
# Episodes: 169, Steps: 215000, Epsilon: 0.83, Avg. Reward per Ep: -20.67
# Episodes: 173, Steps: 220000, Epsilon: 0.82, Avg. Reward per Ep: -20.50
# Episodes: 177, Steps: 225000, Epsilon: 0.82, Avg. Reward per Ep: -20.25
# Episodes: 181, Steps: 230000, Epsilon: 0.82, Avg. Reward per Ep: -20.00
# Episodes: 184, Steps: 235000, Epsilon: 0.81, Avg. Reward per Ep: -19.33
# Episodes: 188, Steps: 240000, Epsilon: 0.81, Avg. Reward per Ep: -19.25
# Episodes: 192, Steps: 245000, Epsilon: 0.80, Avg. Reward per Ep: -20.50
# Episodes: 196, Steps: 250000, Epsilon: 0.80, Avg. Reward per Ep: -20.25
# Episodes: 199, Steps: 255000, Epsilon: 0.80, Avg. Reward per Ep: -19.67
# Episodes: 203, Steps: 260000, Epsilon: 0.79, Avg. Reward per Ep: -19.50
# Episodes: 207, Steps: 265000, Epsilon: 0.79, Avg. Reward per Ep: -20.50
# Episodes: 211, Steps: 270000, Epsilon: 0.79, Avg. Reward per Ep: -20.25
# Episodes: 214, Steps: 275000, Epsilon: 0.78, Avg. Reward per Ep: -20.67
# Episodes: 218, Steps: 280000, Epsilon: 0.78, Avg. Reward per Ep: -19.75
# Episodes: 222, Steps: 285000, Epsilon: 0.78, Avg. Reward per Ep: -20.25
# Episodes: 225, Steps: 290000, Epsilon: 0.77, Avg. Reward per Ep: -20.33
# Episodes: 229, Steps: 295000, Epsilon: 0.77, Avg. Reward per Ep: -19.50
# Episodes: 232, Steps: 300000, Epsilon: 0.77, Avg. Reward per Ep: -19.67
# Episodes: 236, Steps: 305000, Epsilon: 0.76, Avg. Reward per Ep: -20.00
# Episodes: 240, Steps: 310000, Epsilon: 0.76, Avg. Reward per Ep: -19.00
# Episodes: 243, Steps: 315000, Epsilon: 0.76, Avg. Reward per Ep: -19.33
# Episodes: 247, Steps: 320000, Epsilon: 0.75, Avg. Reward per Ep: -19.25
# Episodes: 250, Steps: 325000, Epsilon: 0.75, Avg. Reward per Ep: -18.33
# Episodes: 253, Steps: 330000, Epsilon: 0.75, Avg. Reward per Ep: -19.67
# Episodes: 257, Steps: 335000, Epsilon: 0.74, Avg. Reward per Ep: -20.00
# Episodes: 261, Steps: 340000, Epsilon: 0.74, Avg. Reward per Ep: -20.00
# Episodes: 265, Steps: 345000, Epsilon: 0.74, Avg. Reward per Ep: -20.25
# Episodes: 268, Steps: 350000, Epsilon: 0.73, Avg. Reward per Ep: -18.33
# Episodes: 271, Steps: 355000, Epsilon: 0.73, Avg. Reward per Ep: -19.33
# Episodes: 275, Steps: 360000, Epsilon: 0.73, Avg. Reward per Ep: -19.75
# Episodes: 278, Steps: 365000, Epsilon: 0.72, Avg. Reward per Ep: -19.00
# Episodes: 282, Steps: 370000, Epsilon: 0.72, Avg. Reward per Ep: -20.75
# Episodes: 285, Steps: 375000, Epsilon: 0.72, Avg. Reward per Ep: -19.67
# Episodes: 288, Steps: 380000, Epsilon: 0.72, Avg. Reward per Ep: -20.00
# Episodes: 291, Steps: 385000, Epsilon: 0.71, Avg. Reward per Ep: -19.00
# Episodes: 295, Steps: 390000, Epsilon: 0.71, Avg. Reward per Ep: -19.50
# Episodes: 297, Steps: 395000, Epsilon: 0.71, Avg. Reward per Ep: -17.50
# Episodes: 301, Steps: 400000, Epsilon: 0.70, Avg. Reward per Ep: -19.00
# Episodes: 304, Steps: 405000, Epsilon: 0.70, Avg. Reward per Ep: -18.33
# Episodes: 307, Steps: 410000, Epsilon: 0.70, Avg. Reward per Ep: -19.00
# Episodes: 310, Steps: 415000, Epsilon: 0.69, Avg. Reward per Ep: -18.33
# Episodes: 314, Steps: 420000, Epsilon: 0.69, Avg. Reward per Ep: -19.50
# Episodes: 317, Steps: 425000, Epsilon: 0.69, Avg. Reward per Ep: -19.67
# Episodes: 320, Steps: 430000, Epsilon: 0.69, Avg. Reward per Ep: -18.33
# Episodes: 324, Steps: 435000, Epsilon: 0.68, Avg. Reward per Ep: -19.50
# Episodes: 327, Steps: 440000, Epsilon: 0.68, Avg. Reward per Ep: -18.00
# Episodes: 330, Steps: 445000, Epsilon: 0.68, Avg. Reward per Ep: -20.00
# Episodes: 333, Steps: 450000, Epsilon: 0.67, Avg. Reward per Ep: -19.00
# Episodes: 336, Steps: 455000, Epsilon: 0.67, Avg. Reward per Ep: -20.00
# Episodes: 339, Steps: 460000, Epsilon: 0.67, Avg. Reward per Ep: -19.33
# Episodes: 342, Steps: 465000, Epsilon: 0.67, Avg. Reward per Ep: -19.67
# Episodes: 345, Steps: 470000, Epsilon: 0.66, Avg. Reward per Ep: -18.67
# Episodes: 349, Steps: 475000, Epsilon: 0.66, Avg. Reward per Ep: -18.75
# Episodes: 352, Steps: 480000, Epsilon: 0.66, Avg. Reward per Ep: -19.67
# Episodes: 355, Steps: 485000, Epsilon: 0.65, Avg. Reward per Ep: -19.00
# Episodes: 359, Steps: 490000, Epsilon: 0.65, Avg. Reward per Ep: -19.00
# Episodes: 362, Steps: 495000, Epsilon: 0.65, Avg. Reward per Ep: -19.67
# Episodes: 365, Steps: 500000, Epsilon: 0.65, Avg. Reward per Ep: -19.00
# Episodes: 368, Steps: 505000, Epsilon: 0.64, Avg. Reward per Ep: -18.33
# Episodes: 371, Steps: 510000, Epsilon: 0.64, Avg. Reward per Ep: -18.67
# Episodes: 374, Steps: 515000, Epsilon: 0.64, Avg. Reward per Ep: -18.67
# Episodes: 377, Steps: 520000, Epsilon: 0.64, Avg. Reward per Ep: -19.67
# Episodes: 380, Steps: 525000, Epsilon: 0.63, Avg. Reward per Ep: -19.67
# Episodes: 384, Steps: 530000, Epsilon: 0.63, Avg. Reward per Ep: -20.00
# Episodes: 387, Steps: 535000, Epsilon: 0.63, Avg. Reward per Ep: -19.00
# Episodes: 390, Steps: 540000, Epsilon: 0.62, Avg. Reward per Ep: -16.67
# Episodes: 393, Steps: 545000, Epsilon: 0.62, Avg. Reward per Ep: -19.00
# Episodes: 396, Steps: 550000, Epsilon: 0.62, Avg. Reward per Ep: -18.33
# Episodes: 399, Steps: 555000, Epsilon: 0.62, Avg. Reward per Ep: -17.33
# Episodes: 402, Steps: 560000, Epsilon: 0.61, Avg. Reward per Ep: -20.33
# Episodes: 405, Steps: 565000, Epsilon: 0.61, Avg. Reward per Ep: -19.00
# Episodes: 409, Steps: 570000, Epsilon: 0.61, Avg. Reward per Ep: -19.25
# Episodes: 412, Steps: 575000, Epsilon: 0.61, Avg. Reward per Ep: -19.33
# Episodes: 415, Steps: 580000, Epsilon: 0.60, Avg. Reward per Ep: -17.33
# Episodes: 417, Steps: 585000, Epsilon: 0.60, Avg. Reward per Ep: -16.00
# Episodes: 420, Steps: 590000, Epsilon: 0.60, Avg. Reward per Ep: -19.00
# Episodes: 423, Steps: 595000, Epsilon: 0.60, Avg. Reward per Ep: -19.33
# Episodes: 427, Steps: 600000, Epsilon: 0.59, Avg. Reward per Ep: -19.25
# Episodes: 430, Steps: 605000, Epsilon: 0.59, Avg. Reward per Ep: -18.33
# Episodes: 432, Steps: 610000, Epsilon: 0.59, Avg. Reward per Ep: -20.00
# Episodes: 436, Steps: 615000, Epsilon: 0.59, Avg. Reward per Ep: -19.75
# Episodes: 439, Steps: 620000, Epsilon: 0.58, Avg. Reward per Ep: -19.00
# Episodes: 442, Steps: 625000, Epsilon: 0.58, Avg. Reward per Ep: -19.33
# Episodes: 445, Steps: 630000, Epsilon: 0.58, Avg. Reward per Ep: -19.33
# Episodes: 448, Steps: 635000, Epsilon: 0.58, Avg. Reward per Ep: -19.00
# Episodes: 451, Steps: 640000, Epsilon: 0.57, Avg. Reward per Ep: -18.67
# Episodes: 453, Steps: 645000, Epsilon: 0.57, Avg. Reward per Ep: -18.50
# Episodes: 457, Steps: 650000, Epsilon: 0.57, Avg. Reward per Ep: -18.50
# Episodes: 460, Steps: 655000, Epsilon: 0.57, Avg. Reward per Ep: -19.67
# Episodes: 463, Steps: 660000, Epsilon: 0.57, Avg. Reward per Ep: -18.33
# Episodes: 466, Steps: 665000, Epsilon: 0.56, Avg. Reward per Ep: -18.33
# Episodes: 470, Steps: 670000, Epsilon: 0.56, Avg. Reward per Ep: -20.50
# Episodes: 473, Steps: 675000, Epsilon: 0.56, Avg. Reward per Ep: -19.00
# Episodes: 476, Steps: 680000, Epsilon: 0.56, Avg. Reward per Ep: -19.00
# Episodes: 479, Steps: 685000, Epsilon: 0.55, Avg. Reward per Ep: -18.00
# Episodes: 482, Steps: 690000, Epsilon: 0.55, Avg. Reward per Ep: -18.33
# Episodes: 485, Steps: 695000, Epsilon: 0.55, Avg. Reward per Ep: -18.33
# Episodes: 488, Steps: 700000, Epsilon: 0.55, Avg. Reward per Ep: -17.67
# Episodes: 491, Steps: 705000, Epsilon: 0.54, Avg. Reward per Ep: -19.33
# Episodes: 495, Steps: 710000, Epsilon: 0.54, Avg. Reward per Ep: -19.75
# Episodes: 498, Steps: 715000, Epsilon: 0.54, Avg. Reward per Ep: -20.67
# Episodes: 501, Steps: 720000, Epsilon: 0.54, Avg. Reward per Ep: -18.33
# Episodes: 504, Steps: 725000, Epsilon: 0.54, Avg. Reward per Ep: -19.67
# Episodes: 507, Steps: 730000, Epsilon: 0.53, Avg. Reward per Ep: -20.33
# Episodes: 510, Steps: 735000, Epsilon: 0.53, Avg. Reward per Ep: -17.67
# Episodes: 513, Steps: 740000, Epsilon: 0.53, Avg. Reward per Ep: -19.33
# Episodes: 516, Steps: 745000, Epsilon: 0.53, Avg. Reward per Ep: -19.33
# Episodes: 519, Steps: 750000, Epsilon: 0.53, Avg. Reward per Ep: -19.33
# Episodes: 522, Steps: 755000, Epsilon: 0.52, Avg. Reward per Ep: -17.00
# Episodes: 525, Steps: 760000, Epsilon: 0.52, Avg. Reward per Ep: -18.33
# Episodes: 528, Steps: 765000, Epsilon: 0.52, Avg. Reward per Ep: -18.67
# Episodes: 531, Steps: 770000, Epsilon: 0.52, Avg. Reward per Ep: -19.33
# Episodes: 535, Steps: 775000, Epsilon: 0.51, Avg. Reward per Ep: -19.75
# Episodes: 538, Steps: 780000, Epsilon: 0.51, Avg. Reward per Ep: -19.00
# Episodes: 541, Steps: 785000, Epsilon: 0.51, Avg. Reward per Ep: -19.00
# Episodes: 545, Steps: 790000, Epsilon: 0.51, Avg. Reward per Ep: -19.25
# Episodes: 548, Steps: 795000, Epsilon: 0.51, Avg. Reward per Ep: -19.00
# Episodes: 551, Steps: 800000, Epsilon: 0.50, Avg. Reward per Ep: -17.67
# Episodes: 554, Steps: 805000, Epsilon: 0.50, Avg. Reward per Ep: -18.67
# Episodes: 557, Steps: 810000, Epsilon: 0.50, Avg. Reward per Ep: -19.00
# Episodes: 560, Steps: 815000, Epsilon: 0.50, Avg. Reward per Ep: -18.67
# Episodes: 563, Steps: 820000, Epsilon: 0.50, Avg. Reward per Ep: -18.67
# Episodes: 566, Steps: 825000, Epsilon: 0.49, Avg. Reward per Ep: -17.67
# Episodes: 569, Steps: 830000, Epsilon: 0.49, Avg. Reward per Ep: -19.00
# Episodes: 572, Steps: 835000, Epsilon: 0.49, Avg. Reward per Ep: -19.33
# Episodes: 575, Steps: 840000, Epsilon: 0.49, Avg. Reward per Ep: -19.00
# Episodes: 578, Steps: 845000, Epsilon: 0.49, Avg. Reward per Ep: -18.67
# Episodes: 582, Steps: 850000, Epsilon: 0.48, Avg. Reward per Ep: -19.25
# Episodes: 585, Steps: 855000, Epsilon: 0.48, Avg. Reward per Ep: -18.33
# Episodes: 588, Steps: 860000, Epsilon: 0.48, Avg. Reward per Ep: -19.67
# Episodes: 591, Steps: 865000, Epsilon: 0.48, Avg. Reward per Ep: -17.00
# Episodes: 594, Steps: 870000, Epsilon: 0.48, Avg. Reward per Ep: -20.00
# Episodes: 597, Steps: 875000, Epsilon: 0.48, Avg. Reward per Ep: -17.00
# Episodes: 600, Steps: 880000, Epsilon: 0.47, Avg. Reward per Ep: -19.67
# Episodes: 603, Steps: 885000, Epsilon: 0.47, Avg. Reward per Ep: -18.33
# Episodes: 605, Steps: 890000, Epsilon: 0.47, Avg. Reward per Ep: -18.50
# Episodes: 608, Steps: 895000, Epsilon: 0.47, Avg. Reward per Ep: -19.33
# Episodes: 611, Steps: 900000, Epsilon: 0.47, Avg. Reward per Ep: -18.33
# Episodes: 614, Steps: 905000, Epsilon: 0.46, Avg. Reward per Ep: -17.33
# Episodes: 617, Steps: 910000, Epsilon: 0.46, Avg. Reward per Ep: -20.00
# Episodes: 620, Steps: 915000, Epsilon: 0.46, Avg. Reward per Ep: -19.00
# Episodes: 623, Steps: 920000, Epsilon: 0.46, Avg. Reward per Ep: -18.67
# Episodes: 626, Steps: 925000, Epsilon: 0.46, Avg. Reward per Ep: -18.67
# Episodes: 629, Steps: 930000, Epsilon: 0.46, Avg. Reward per Ep: -18.67
# Episodes: 631, Steps: 935000, Epsilon: 0.45, Avg. Reward per Ep: -18.50
# Episodes: 634, Steps: 940000, Epsilon: 0.45, Avg. Reward per Ep: -19.33
# Episodes: 637, Steps: 945000, Epsilon: 0.45, Avg. Reward per Ep: -18.67
# Episodes: 640, Steps: 950000, Epsilon: 0.45, Avg. Reward per Ep: -19.33
# Episodes: 644, Steps: 955000, Epsilon: 0.45, Avg. Reward per Ep: -20.25
# Episodes: 647, Steps: 960000, Epsilon: 0.44, Avg. Reward per Ep: -19.67
# Episodes: 650, Steps: 965000, Epsilon: 0.44, Avg. Reward per Ep: -17.33
# Episodes: 653, Steps: 970000, Epsilon: 0.44, Avg. Reward per Ep: -20.00
# Episodes: 657, Steps: 975000, Epsilon: 0.44, Avg. Reward per Ep: -19.75
# Episodes: 660, Steps: 980000, Epsilon: 0.44, Avg. Reward per Ep: -19.67
# Episodes: 663, Steps: 985000, Epsilon: 0.44, Avg. Reward per Ep: -19.67
# Episodes: 666, Steps: 990000, Epsilon: 0.43, Avg. Reward per Ep: -19.00
# Episodes: 670, Steps: 995000, Epsilon: 0.43, Avg. Reward per Ep: -19.00
# Episodes: 672, Steps: 1000000, Epsilon: 0.43, Avg. Reward per Ep: -17.00
# Episodes: 675, Steps: 1005000, Epsilon: 0.43, Avg. Reward per Ep: -18.00
# Episodes: 679, Steps: 1010000, Epsilon: 0.43, Avg. Reward per Ep: -18.50
# Episodes: 682, Steps: 1015000, Epsilon: 0.43, Avg. Reward per Ep: -20.00
# Episodes: 686, Steps: 1020000, Epsilon: 0.42, Avg. Reward per Ep: -20.00
# Episodes: 690, Steps: 1025000, Epsilon: 0.42, Avg. Reward per Ep: -20.00
# Episodes: 693, Steps: 1030000, Epsilon: 0.42, Avg. Reward per Ep: -18.67
# Episodes: 696, Steps: 1035000, Epsilon: 0.42, Avg. Reward per Ep: -19.00
# Episodes: 699, Steps: 1040000, Epsilon: 0.42, Avg. Reward per Ep: -20.00
# Episodes: 703, Steps: 1045000, Epsilon: 0.42, Avg. Reward per Ep: -18.75
# Episodes: 706, Steps: 1050000, Epsilon: 0.41, Avg. Reward per Ep: -19.00
# Episodes: 709, Steps: 1055000, Epsilon: 0.41, Avg. Reward per Ep: -19.33
# Episodes: 712, Steps: 1060000, Epsilon: 0.41, Avg. Reward per Ep: -19.00
# Episodes: 714, Steps: 1065000, Epsilon: 0.41, Avg. Reward per Ep: -18.00
# Episodes: 718, Steps: 1070000, Epsilon: 0.41, Avg. Reward per Ep: -19.25
# Episodes: 721, Steps: 1075000, Epsilon: 0.41, Avg. Reward per Ep: -19.33
# Episodes: 724, Steps: 1080000, Epsilon: 0.41, Avg. Reward per Ep: -18.67
# Episodes: 727, Steps: 1085000, Epsilon: 0.40, Avg. Reward per Ep: -19.33
# Episodes: 731, Steps: 1090000, Epsilon: 0.40, Avg. Reward per Ep: -20.25
# Episodes: 734, Steps: 1095000, Epsilon: 0.40, Avg. Reward per Ep: -20.33
# Episodes: 737, Steps: 1100000, Epsilon: 0.40, Avg. Reward per Ep: -19.00
# Episodes: 740, Steps: 1105000, Epsilon: 0.40, Avg. Reward per Ep: -19.67
# Episodes: 743, Steps: 1110000, Epsilon: 0.40, Avg. Reward per Ep: -17.33
# Episodes: 746, Steps: 1115000, Epsilon: 0.40, Avg. Reward per Ep: -19.33
# Episodes: 749, Steps: 1120000, Epsilon: 0.39, Avg. Reward per Ep: -19.00
# Episodes: 752, Steps: 1125000, Epsilon: 0.39, Avg. Reward per Ep: -17.67
# Episodes: 756, Steps: 1130000, Epsilon: 0.39, Avg. Reward per Ep: -20.00
# Episodes: 759, Steps: 1135000, Epsilon: 0.39, Avg. Reward per Ep: -17.67
# Episodes: 762, Steps: 1140000, Epsilon: 0.39, Avg. Reward per Ep: -17.00
# Episodes: 765, Steps: 1145000, Epsilon: 0.39, Avg. Reward per Ep: -18.67
# Episodes: 768, Steps: 1150000, Epsilon: 0.38, Avg. Reward per Ep: -18.67
# Episodes: 770, Steps: 1155000, Epsilon: 0.38, Avg. Reward per Ep: -19.00
# Episodes: 774, Steps: 1160000, Epsilon: 0.38, Avg. Reward per Ep: -19.00
# Episodes: 777, Steps: 1165000, Epsilon: 0.38, Avg. Reward per Ep: -19.00
# Episodes: 780, Steps: 1170000, Epsilon: 0.38, Avg. Reward per Ep: -18.67
# Episodes: 784, Steps: 1175000, Epsilon: 0.38, Avg. Reward per Ep: -19.50
# Episodes: 787, Steps: 1180000, Epsilon: 0.38, Avg. Reward per Ep: -20.33
# Episodes: 791, Steps: 1185000, Epsilon: 0.38, Avg. Reward per Ep: -19.50
# Episodes: 794, Steps: 1190000, Epsilon: 0.37, Avg. Reward per Ep: -20.33
# Episodes: 797, Steps: 1195000, Epsilon: 0.37, Avg. Reward per Ep: -19.00
# Episodes: 800, Steps: 1200000, Epsilon: 0.37, Avg. Reward per Ep: -18.67
# Episodes: 803, Steps: 1205000, Epsilon: 0.37, Avg. Reward per Ep: -19.33
# Episodes: 806, Steps: 1210000, Epsilon: 0.37, Avg. Reward per Ep: -20.00
# Episodes: 810, Steps: 1215000, Epsilon: 0.37, Avg. Reward per Ep: -19.75
# Episodes: 813, Steps: 1220000, Epsilon: 0.37, Avg. Reward per Ep: -19.33
# Episodes: 815, Steps: 1225000, Epsilon: 0.36, Avg. Reward per Ep: -21.00
# Episodes: 819, Steps: 1230000, Epsilon: 0.36, Avg. Reward per Ep: -19.50
# Episodes: 822, Steps: 1235000, Epsilon: 0.36, Avg. Reward per Ep: -19.33
# Episodes: 826, Steps: 1240000, Epsilon: 0.36, Avg. Reward per Ep: -19.25
# Episodes: 829, Steps: 1245000, Epsilon: 0.36, Avg. Reward per Ep: -20.00
# Episodes: 832, Steps: 1250000, Epsilon: 0.36, Avg. Reward per Ep: -19.00
# Episodes: 835, Steps: 1255000, Epsilon: 0.36, Avg. Reward per Ep: -19.67
# Episodes: 838, Steps: 1260000, Epsilon: 0.36, Avg. Reward per Ep: -19.33
# Episodes: 841, Steps: 1265000, Epsilon: 0.35, Avg. Reward per Ep: -18.33
# Episodes: 845, Steps: 1270000, Epsilon: 0.35, Avg. Reward per Ep: -19.75
# Episodes: 848, Steps: 1275000, Epsilon: 0.35, Avg. Reward per Ep: -19.67
# Episodes: 851, Steps: 1280000, Epsilon: 0.35, Avg. Reward per Ep: -19.67
# Episodes: 855, Steps: 1285000, Epsilon: 0.35, Avg. Reward per Ep: -19.50
# Episodes: 858, Steps: 1290000, Epsilon: 0.35, Avg. Reward per Ep: -18.67
# Episodes: 861, Steps: 1295000, Epsilon: 0.35, Avg. Reward per Ep: -18.67
# Episodes: 864, Steps: 1300000, Epsilon: 0.35, Avg. Reward per Ep: -20.00
# Episodes: 866, Steps: 1305000, Epsilon: 0.34, Avg. Reward per Ep: -18.50
# Episodes: 869, Steps: 1310000, Epsilon: 0.34, Avg. Reward per Ep: -18.00
# Episodes: 872, Steps: 1315000, Epsilon: 0.34, Avg. Reward per Ep: -20.00
# Episodes: 875, Steps: 1320000, Epsilon: 0.34, Avg. Reward per Ep: -19.00
# Episodes: 878, Steps: 1325000, Epsilon: 0.34, Avg. Reward per Ep: -20.00
# Episodes: 882, Steps: 1330000, Epsilon: 0.34, Avg. Reward per Ep: -18.50
# Episodes: 884, Steps: 1335000, Epsilon: 0.34, Avg. Reward per Ep: -17.00
# Episodes: 888, Steps: 1340000, Epsilon: 0.34, Avg. Reward per Ep: -19.50
# Episodes: 891, Steps: 1345000, Epsilon: 0.33, Avg. Reward per Ep: -19.67
# Episodes: 894, Steps: 1350000, Epsilon: 0.33, Avg. Reward per Ep: -19.00
# Episodes: 898, Steps: 1355000, Epsilon: 0.33, Avg. Reward per Ep: -20.25
# Episodes: 901, Steps: 1360000, Epsilon: 0.33, Avg. Reward per Ep: -18.67
# Episodes: 903, Steps: 1365000, Epsilon: 0.33, Avg. Reward per Ep: -20.00
# Episodes: 906, Steps: 1370000, Epsilon: 0.33, Avg. Reward per Ep: -16.67
# Episodes: 909, Steps: 1375000, Epsilon: 0.33, Avg. Reward per Ep: -19.33
# Episodes: 912, Steps: 1380000, Epsilon: 0.33, Avg. Reward per Ep: -18.67
# Episodes: 915, Steps: 1385000, Epsilon: 0.33, Avg. Reward per Ep: -19.67
# Episodes: 918, Steps: 1390000, Epsilon: 0.32, Avg. Reward per Ep: -17.33
# Episodes: 920, Steps: 1395000, Epsilon: 0.32, Avg. Reward per Ep: -19.00
# Episodes: 923, Steps: 1400000, Epsilon: 0.32, Avg. Reward per Ep: -19.33
# Episodes: 926, Steps: 1405000, Epsilon: 0.32, Avg. Reward per Ep: -19.33
# Episodes: 929, Steps: 1410000, Epsilon: 0.32, Avg. Reward per Ep: -18.33
# Episodes: 932, Steps: 1415000, Epsilon: 0.32, Avg. Reward per Ep: -20.67
# Episodes: 934, Steps: 1420000, Epsilon: 0.32, Avg. Reward per Ep: -19.00
# Episodes: 937, Steps: 1425000, Epsilon: 0.32, Avg. Reward per Ep: -19.67
# Episodes: 940, Steps: 1430000, Epsilon: 0.32, Avg. Reward per Ep: -19.33
# Episodes: 943, Steps: 1435000, Epsilon: 0.31, Avg. Reward per Ep: -17.67
# Episodes: 946, Steps: 1440000, Epsilon: 0.31, Avg. Reward per Ep: -19.67
# Episodes: 949, Steps: 1445000, Epsilon: 0.31, Avg. Reward per Ep: -19.67
# Episodes: 952, Steps: 1450000, Epsilon: 0.31, Avg. Reward per Ep: -18.00
# Episodes: 955, Steps: 1455000, Epsilon: 0.31, Avg. Reward per Ep: -20.00
# Episodes: 957, Steps: 1460000, Epsilon: 0.31, Avg. Reward per Ep: -19.00
# Episodes: 960, Steps: 1465000, Epsilon: 0.31, Avg. Reward per Ep: -18.00
# Episodes: 963, Steps: 1470000, Epsilon: 0.31, Avg. Reward per Ep: -19.33
# Episodes: 966, Steps: 1475000, Epsilon: 0.31, Avg. Reward per Ep: -19.00
# Episodes: 969, Steps: 1480000, Epsilon: 0.30, Avg. Reward per Ep: -18.67
# Episodes: 972, Steps: 1485000, Epsilon: 0.30, Avg. Reward per Ep: -18.67
# Episodes: 975, Steps: 1490000, Epsilon: 0.30, Avg. Reward per Ep: -17.67
# Episodes: 978, Steps: 1495000, Epsilon: 0.30, Avg. Reward per Ep: -18.33
# Episodes: 981, Steps: 1500000, Epsilon: 0.30, Avg. Reward per Ep: -17.67
# Episodes: 984, Steps: 1505000, Epsilon: 0.30, Avg. Reward per Ep: -19.00
# Episodes: 986, Steps: 1510000, Epsilon: 0.30, Avg. Reward per Ep: -18.00
# Episodes: 989, Steps: 1515000, Epsilon: 0.30, Avg. Reward per Ep: -19.00
# Episodes: 992, Steps: 1520000, Epsilon: 0.30, Avg. Reward per Ep: -17.33
# Episodes: 995, Steps: 1525000, Epsilon: 0.30, Avg. Reward per Ep: -18.00
# Episodes: 997, Steps: 1530000, Epsilon: 0.29, Avg. Reward per Ep: -17.00
# Episodes: 999, Steps: 1535000, Epsilon: 0.29, Avg. Reward per Ep: -19.00
# Episodes: 1002, Steps: 1540000, Epsilon: 0.29, Avg. Reward per Ep: -16.33
# Episodes: 1005, Steps: 1545000, Epsilon: 0.29, Avg. Reward per Ep: -17.67
# Episodes: 1008, Steps: 1550000, Epsilon: 0.29, Avg. Reward per Ep: -17.33
# Episodes: 1010, Steps: 1555000, Epsilon: 0.29, Avg. Reward per Ep: -18.00
# Episodes: 1013, Steps: 1560000, Epsilon: 0.29, Avg. Reward per Ep: -15.33
# Episodes: 1015, Steps: 1565000, Epsilon: 0.29, Avg. Reward per Ep: -18.00
# Episodes: 1018, Steps: 1570000, Epsilon: 0.29, Avg. Reward per Ep: -18.33
# Episodes: 1021, Steps: 1575000, Epsilon: 0.29, Avg. Reward per Ep: -19.00
# Episodes: 1024, Steps: 1580000, Epsilon: 0.29, Avg. Reward per Ep: -16.67
# Episodes: 1026, Steps: 1585000, Epsilon: 0.28, Avg. Reward per Ep: -18.50
# Episodes: 1029, Steps: 1590000, Epsilon: 0.28, Avg. Reward per Ep: -17.67
# Episodes: 1031, Steps: 1595000, Epsilon: 0.28, Avg. Reward per Ep: -17.00
# Episodes: 1034, Steps: 1600000, Epsilon: 0.28, Avg. Reward per Ep: -16.33
# Episodes: 1037, Steps: 1605000, Epsilon: 0.28, Avg. Reward per Ep: -17.33
# Episodes: 1040, Steps: 1610000, Epsilon: 0.28, Avg. Reward per Ep: -18.67
# Episodes: 1043, Steps: 1615000, Epsilon: 0.28, Avg. Reward per Ep: -18.67
# Episodes: 1045, Steps: 1620000, Epsilon: 0.28, Avg. Reward per Ep: -17.50
# Episodes: 1048, Steps: 1625000, Epsilon: 0.28, Avg. Reward per Ep: -17.33
# Episodes: 1051, Steps: 1630000, Epsilon: 0.28, Avg. Reward per Ep: -18.00
# Episodes: 1054, Steps: 1635000, Epsilon: 0.28, Avg. Reward per Ep: -19.67
# Episodes: 1057, Steps: 1640000, Epsilon: 0.27, Avg. Reward per Ep: -17.33
# Episodes: 1059, Steps: 1645000, Epsilon: 0.27, Avg. Reward per Ep: -17.00
# Episodes: 1062, Steps: 1650000, Epsilon: 0.27, Avg. Reward per Ep: -17.67
# Episodes: 1065, Steps: 1655000, Epsilon: 0.27, Avg. Reward per Ep: -17.67
# Episodes: 1067, Steps: 1660000, Epsilon: 0.27, Avg. Reward per Ep: -18.50
# Episodes: 1070, Steps: 1665000, Epsilon: 0.27, Avg. Reward per Ep: -18.33
# Episodes: 1073, Steps: 1670000, Epsilon: 0.27, Avg. Reward per Ep: -19.33
# Episodes: 1075, Steps: 1675000, Epsilon: 0.27, Avg. Reward per Ep: -19.00
# Episodes: 1078, Steps: 1680000, Epsilon: 0.27, Avg. Reward per Ep: -18.33
# Episodes: 1080, Steps: 1685000, Epsilon: 0.27, Avg. Reward per Ep: -16.50
# Episodes: 1083, Steps: 1690000, Epsilon: 0.27, Avg. Reward per Ep: -20.00
# Episodes: 1086, Steps: 1695000, Epsilon: 0.27, Avg. Reward per Ep: -17.33
# Episodes: 1089, Steps: 1700000, Epsilon: 0.26, Avg. Reward per Ep: -17.67
# Episodes: 1091, Steps: 1705000, Epsilon: 0.26, Avg. Reward per Ep: -17.50
# Episodes: 1094, Steps: 1710000, Epsilon: 0.26, Avg. Reward per Ep: -18.00
# Episodes: 1097, Steps: 1715000, Epsilon: 0.26, Avg. Reward per Ep: -18.33
# Episodes: 1099, Steps: 1720000, Epsilon: 0.26, Avg. Reward per Ep: -18.50
# Episodes: 1102, Steps: 1725000, Epsilon: 0.26, Avg. Reward per Ep: -16.00
# Episodes: 1104, Steps: 1730000, Epsilon: 0.26, Avg. Reward per Ep: -17.50
# Episodes: 1106, Steps: 1735000, Epsilon: 0.26, Avg. Reward per Ep: -20.50
# Episodes: 1109, Steps: 1740000, Epsilon: 0.26, Avg. Reward per Ep: -19.00
# Episodes: 1111, Steps: 1745000, Epsilon: 0.26, Avg. Reward per Ep: -16.50
# Episodes: 1114, Steps: 1750000, Epsilon: 0.26, Avg. Reward per Ep: -18.33
# Episodes: 1116, Steps: 1755000, Epsilon: 0.26, Avg. Reward per Ep: -14.50
# Episodes: 1119, Steps: 1760000, Epsilon: 0.25, Avg. Reward per Ep: -17.67
# Episodes: 1121, Steps: 1765000, Epsilon: 0.25, Avg. Reward per Ep: -17.00
# Episodes: 1124, Steps: 1770000, Epsilon: 0.25, Avg. Reward per Ep: -16.33
# Episodes: 1127, Steps: 1775000, Epsilon: 0.25, Avg. Reward per Ep: -18.67
# Episodes: 1129, Steps: 1780000, Epsilon: 0.25, Avg. Reward per Ep: -18.50
# Episodes: 1132, Steps: 1785000, Epsilon: 0.25, Avg. Reward per Ep: -19.33
# Episodes: 1135, Steps: 1790000, Epsilon: 0.25, Avg. Reward per Ep: -17.67
# Episodes: 1137, Steps: 1795000, Epsilon: 0.25, Avg. Reward per Ep: -16.50
# Episodes: 1140, Steps: 1800000, Epsilon: 0.25, Avg. Reward per Ep: -19.33
# Episodes: 1142, Steps: 1805000, Epsilon: 0.25, Avg. Reward per Ep: -18.50
# Episodes: 1145, Steps: 1810000, Epsilon: 0.25, Avg. Reward per Ep: -17.67
# Episodes: 1148, Steps: 1815000, Epsilon: 0.25, Avg. Reward per Ep: -16.33
# Episodes: 1150, Steps: 1820000, Epsilon: 0.25, Avg. Reward per Ep: -18.00
# Episodes: 1153, Steps: 1825000, Epsilon: 0.25, Avg. Reward per Ep: -18.00
# Episodes: 1156, Steps: 1830000, Epsilon: 0.24, Avg. Reward per Ep: -17.67
# Episodes: 1159, Steps: 1835000, Epsilon: 0.24, Avg. Reward per Ep: -17.00
# Episodes: 1161, Steps: 1840000, Epsilon: 0.24, Avg. Reward per Ep: -16.50
# Episodes: 1164, Steps: 1845000, Epsilon: 0.24, Avg. Reward per Ep: -17.67
# Episodes: 1167, Steps: 1850000, Epsilon: 0.24, Avg. Reward per Ep: -19.00
# Episodes: 1169, Steps: 1855000, Epsilon: 0.24, Avg. Reward per Ep: -17.50
# Episodes: 1172, Steps: 1860000, Epsilon: 0.24, Avg. Reward per Ep: -19.67
# Episodes: 1174, Steps: 1865000, Epsilon: 0.24, Avg. Reward per Ep: -18.50
# Episodes: 1177, Steps: 1870000, Epsilon: 0.24, Avg. Reward per Ep: -18.33
# Episodes: 1179, Steps: 1875000, Epsilon: 0.24, Avg. Reward per Ep: -19.00
# Episodes: 1182, Steps: 1880000, Epsilon: 0.24, Avg. Reward per Ep: -17.67
# Episodes: 1184, Steps: 1885000, Epsilon: 0.24, Avg. Reward per Ep: -17.00
# Episodes: 1187, Steps: 1890000, Epsilon: 0.24, Avg. Reward per Ep: -18.67
# Episodes: 1190, Steps: 1895000, Epsilon: 0.24, Avg. Reward per Ep: -17.67
# Episodes: 1193, Steps: 1900000, Epsilon: 0.23, Avg. Reward per Ep: -19.00
# Episodes: 1195, Steps: 1905000, Epsilon: 0.23, Avg. Reward per Ep: -16.50
# Episodes: 1198, Steps: 1910000, Epsilon: 0.23, Avg. Reward per Ep: -17.67
# Episodes: 1200, Steps: 1915000, Epsilon: 0.23, Avg. Reward per Ep: -17.00
# Episodes: 1202, Steps: 1920000, Epsilon: 0.23, Avg. Reward per Ep: -19.00
# Episodes: 1205, Steps: 1925000, Epsilon: 0.23, Avg. Reward per Ep: -19.00
# Episodes: 1208, Steps: 1930000, Epsilon: 0.23, Avg. Reward per Ep: -17.33
# Episodes: 1211, Steps: 1935000, Epsilon: 0.23, Avg. Reward per Ep: -18.00
# Episodes: 1214, Steps: 1940000, Epsilon: 0.23, Avg. Reward per Ep: -19.00
# Episodes: 1216, Steps: 1945000, Epsilon: 0.23, Avg. Reward per Ep: -15.50
# Episodes: 1219, Steps: 1950000, Epsilon: 0.23, Avg. Reward per Ep: -18.33
# Episodes: 1221, Steps: 1955000, Epsilon: 0.23, Avg. Reward per Ep: -18.00
# Episodes: 1223, Steps: 1960000, Epsilon: 0.23, Avg. Reward per Ep: -16.00
# Episodes: 1225, Steps: 1965000, Epsilon: 0.23, Avg. Reward per Ep: -19.00
# Episodes: 1228, Steps: 1970000, Epsilon: 0.23, Avg. Reward per Ep: -14.33
# Episodes: 1230, Steps: 1975000, Epsilon: 0.22, Avg. Reward per Ep: -17.00
# Episodes: 1232, Steps: 1980000, Epsilon: 0.22, Avg. Reward per Ep: -15.00
# Episodes: 1235, Steps: 1985000, Epsilon: 0.22, Avg. Reward per Ep: -18.33
# Episodes: 1238, Steps: 1990000, Epsilon: 0.22, Avg. Reward per Ep: -18.00
# Episodes: 1240, Steps: 1995000, Epsilon: 0.22, Avg. Reward per Ep: -16.50
# Episodes: 1242, Steps: 2000000, Epsilon: 0.22, Avg. Reward per Ep: -18.00
# Episodes: 1244, Steps: 2005000, Epsilon: 0.22, Avg. Reward per Ep: -15.50
# Episodes: 1246, Steps: 2010000, Epsilon: 0.22, Avg. Reward per Ep: -13.00
# Episodes: 1249, Steps: 2015000, Epsilon: 0.22, Avg. Reward per Ep: -18.00
# Episodes: 1252, Steps: 2020000, Epsilon: 0.22, Avg. Reward per Ep: -18.33
# Episodes: 1254, Steps: 2025000, Epsilon: 0.22, Avg. Reward per Ep: -15.50
# Episodes: 1256, Steps: 2030000, Epsilon: 0.22, Avg. Reward per Ep: -16.50
# Episodes: 1259, Steps: 2035000, Epsilon: 0.22, Avg. Reward per Ep: -18.00
# Episodes: 1262, Steps: 2040000, Epsilon: 0.22, Avg. Reward per Ep: -17.00
# Episodes: 1264, Steps: 2045000, Epsilon: 0.22, Avg. Reward per Ep: -17.00
# Episodes: 1267, Steps: 2050000, Epsilon: 0.22, Avg. Reward per Ep: -20.67
# Episodes: 1270, Steps: 2055000, Epsilon: 0.22, Avg. Reward per Ep: -17.33
# Episodes: 1272, Steps: 2060000, Epsilon: 0.21, Avg. Reward per Ep: -15.00
# Episodes: 1274, Steps: 2065000, Epsilon: 0.21, Avg. Reward per Ep: -18.00
# Episodes: 1277, Steps: 2070000, Epsilon: 0.21, Avg. Reward per Ep: -18.00
# Episodes: 1280, Steps: 2075000, Epsilon: 0.21, Avg. Reward per Ep: -18.00
# Episodes: 1282, Steps: 2080000, Epsilon: 0.21, Avg. Reward per Ep: -18.50
# Episodes: 1284, Steps: 2085000, Epsilon: 0.21, Avg. Reward per Ep: -14.00
# Episodes: 1287, Steps: 2090000, Epsilon: 0.21, Avg. Reward per Ep: -16.67
# Episodes: 1289, Steps: 2095000, Epsilon: 0.21, Avg. Reward per Ep: -15.50
# Episodes: 1291, Steps: 2100000, Epsilon: 0.21, Avg. Reward per Ep: -16.50
# Episodes: 1294, Steps: 2105000, Epsilon: 0.21, Avg. Reward per Ep: -18.00
# Episodes: 1297, Steps: 2110000, Epsilon: 0.21, Avg. Reward per Ep: -18.67
# Episodes: 1299, Steps: 2115000, Epsilon: 0.21, Avg. Reward per Ep: -17.50
# Episodes: 1302, Steps: 2120000, Epsilon: 0.21, Avg. Reward per Ep: -17.67
# Episodes: 1304, Steps: 2125000, Epsilon: 0.21, Avg. Reward per Ep: -17.50
# Episodes: 1306, Steps: 2130000, Epsilon: 0.21, Avg. Reward per Ep: -13.00
# Episodes: 1308, Steps: 2135000, Epsilon: 0.21, Avg. Reward per Ep: -14.00
# Episodes: 1310, Steps: 2140000, Epsilon: 0.21, Avg. Reward per Ep: -18.00
# Episodes: 1313, Steps: 2145000, Epsilon: 0.21, Avg. Reward per Ep: -17.00
# Episodes: 1315, Steps: 2150000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1317, Steps: 2155000, Epsilon: 0.20, Avg. Reward per Ep: -17.50
# Episodes: 1319, Steps: 2160000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1322, Steps: 2165000, Epsilon: 0.20, Avg. Reward per Ep: -18.67
# Episodes: 1324, Steps: 2170000, Epsilon: 0.20, Avg. Reward per Ep: -16.00
# Episodes: 1326, Steps: 2175000, Epsilon: 0.20, Avg. Reward per Ep: -19.00
# Episodes: 1328, Steps: 2180000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1331, Steps: 2185000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1333, Steps: 2190000, Epsilon: 0.20, Avg. Reward per Ep: -18.50
# Episodes: 1336, Steps: 2195000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1339, Steps: 2200000, Epsilon: 0.20, Avg. Reward per Ep: -18.33
# Episodes: 1341, Steps: 2205000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1343, Steps: 2210000, Epsilon: 0.20, Avg. Reward per Ep: -19.50
# Episodes: 1345, Steps: 2215000, Epsilon: 0.20, Avg. Reward per Ep: -17.50
# Episodes: 1347, Steps: 2220000, Epsilon: 0.20, Avg. Reward per Ep: -17.00
# Episodes: 1350, Steps: 2225000, Epsilon: 0.20, Avg. Reward per Ep: -18.00
# Episodes: 1352, Steps: 2230000, Epsilon: 0.20, Avg. Reward per Ep: -15.50
# Episodes: 1354, Steps: 2235000, Epsilon: 0.20, Avg. Reward per Ep: -16.00
# Episodes: 1357, Steps: 2240000, Epsilon: 0.20, Avg. Reward per Ep: -17.00
# Episodes: 1359, Steps: 2245000, Epsilon: 0.20, Avg. Reward per Ep: -16.00
# Episodes: 1362, Steps: 2250000, Epsilon: 0.19, Avg. Reward per Ep: -19.00
# Episodes: 1364, Steps: 2255000, Epsilon: 0.19, Avg. Reward per Ep: -17.00
# Episodes: 1366, Steps: 2260000, Epsilon: 0.19, Avg. Reward per Ep: -15.50
# Episodes: 1368, Steps: 2265000, Epsilon: 0.19, Avg. Reward per Ep: -17.00
# Episodes: 1371, Steps: 2270000, Epsilon: 0.19, Avg. Reward per Ep: -18.00
# Episodes: 1373, Steps: 2275000, Epsilon: 0.19, Avg. Reward per Ep: -17.00
# Episodes: 1375, Steps: 2280000, Epsilon: 0.19, Avg. Reward per Ep: -15.00
# Episodes: 1377, Steps: 2285000, Epsilon: 0.19, Avg. Reward per Ep: -16.00
# Episodes: 1380, Steps: 2290000, Epsilon: 0.19, Avg. Reward per Ep: -18.67
# Episodes: 1383, Steps: 2295000, Epsilon: 0.19, Avg. Reward per Ep: -17.67
# Episodes: 1385, Steps: 2300000, Epsilon: 0.19, Avg. Reward per Ep: -16.00
# Episodes: 1387, Steps: 2305000, Epsilon: 0.19, Avg. Reward per Ep: -17.00
# Episodes: 1390, Steps: 2310000, Epsilon: 0.19, Avg. Reward per Ep: -18.67
# Episodes: 1393, Steps: 2315000, Epsilon: 0.19, Avg. Reward per Ep: -17.00
# Episodes: 1395, Steps: 2320000, Epsilon: 0.19, Avg. Reward per Ep: -18.50
# Episodes: 1398, Steps: 2325000, Epsilon: 0.19, Avg. Reward per Ep: -18.33
# Episodes: 1400, Steps: 2330000, Epsilon: 0.19, Avg. Reward per Ep: -17.50
# Episodes: 1402, Steps: 2335000, Epsilon: 0.19, Avg. Reward per Ep: -16.00
# Episodes: 1405, Steps: 2340000, Epsilon: 0.19, Avg. Reward per Ep: -16.33
# Episodes: 1407, Steps: 2345000, Epsilon: 0.19, Avg. Reward per Ep: -18.50
# Episodes: 1409, Steps: 2350000, Epsilon: 0.19, Avg. Reward per Ep: -16.50
# Episodes: 1412, Steps: 2355000, Epsilon: 0.19, Avg. Reward per Ep: -18.33
# Episodes: 1414, Steps: 2360000, Epsilon: 0.18, Avg. Reward per Ep: -16.50
# Episodes: 1416, Steps: 2365000, Epsilon: 0.18, Avg. Reward per Ep: -17.50
# Episodes: 1419, Steps: 2370000, Epsilon: 0.18, Avg. Reward per Ep: -19.33
# Episodes: 1421, Steps: 2375000, Epsilon: 0.18, Avg. Reward per Ep: -18.00
# Episodes: 1424, Steps: 2380000, Epsilon: 0.18, Avg. Reward per Ep: -19.00
# Episodes: 1426, Steps: 2385000, Epsilon: 0.18, Avg. Reward per Ep: -15.50
# Episodes: 1429, Steps: 2390000, Epsilon: 0.18, Avg. Reward per Ep: -18.67
# Episodes: 1432, Steps: 2395000, Epsilon: 0.18, Avg. Reward per Ep: -18.00
# Episodes: 1434, Steps: 2400000, Epsilon: 0.18, Avg. Reward per Ep: -15.00
# Episodes: 1436, Steps: 2405000, Epsilon: 0.18, Avg. Reward per Ep: -17.00
# Episodes: 1438, Steps: 2410000, Epsilon: 0.18, Avg. Reward per Ep: -17.50
# Episodes: 1441, Steps: 2415000, Epsilon: 0.18, Avg. Reward per Ep: -16.33
# Episodes: 1443, Steps: 2420000, Epsilon: 0.18, Avg. Reward per Ep: -19.50
# Episodes: 1446, Steps: 2425000, Epsilon: 0.18, Avg. Reward per Ep: -16.00
# Episodes: 1448, Steps: 2430000, Epsilon: 0.18, Avg. Reward per Ep: -16.00
# Episodes: 1451, Steps: 2435000, Epsilon: 0.18, Avg. Reward per Ep: -19.67
# Episodes: 1453, Steps: 2440000, Epsilon: 0.18, Avg. Reward per Ep: -18.50
# Episodes: 1455, Steps: 2445000, Epsilon: 0.18, Avg. Reward per Ep: -16.00
# Episodes: 1458, Steps: 2450000, Epsilon: 0.18, Avg. Reward per Ep: -17.33
# Episodes: 1460, Steps: 2455000, Epsilon: 0.18, Avg. Reward per Ep: -17.00
# Episodes: 1462, Steps: 2460000, Epsilon: 0.18, Avg. Reward per Ep: -18.50
# Episodes: 1465, Steps: 2465000, Epsilon: 0.18, Avg. Reward per Ep: -17.00
# Episodes: 1467, Steps: 2470000, Epsilon: 0.18, Avg. Reward per Ep: -18.00
# Episodes: 1469, Steps: 2475000, Epsilon: 0.18, Avg. Reward per Ep: -18.50
# Episodes: 1472, Steps: 2480000, Epsilon: 0.18, Avg. Reward per Ep: -18.00
# Episodes: 1474, Steps: 2485000, Epsilon: 0.17, Avg. Reward per Ep: -17.50
# Episodes: 1477, Steps: 2490000, Epsilon: 0.17, Avg. Reward per Ep: -19.33
# Episodes: 1479, Steps: 2495000, Epsilon: 0.17, Avg. Reward per Ep: -19.00
# Episodes: 1481, Steps: 2500000, Epsilon: 0.17, Avg. Reward per Ep: -17.00
# Episodes: 1484, Steps: 2505000, Epsilon: 0.17, Avg. Reward per Ep: -19.00
# Episodes: 1487, Steps: 2510000, Epsilon: 0.17, Avg. Reward per Ep: -18.33
# Episodes: 1490, Steps: 2515000, Epsilon: 0.17, Avg. Reward per Ep: -17.67
# Episodes: 1492, Steps: 2520000, Epsilon: 0.17, Avg. Reward per Ep: -18.00
# Episodes: 1495, Steps: 2525000, Epsilon: 0.17, Avg. Reward per Ep: -17.00
# Episodes: 1497, Steps: 2530000, Epsilon: 0.17, Avg. Reward per Ep: -16.00
# Episodes: 1499, Steps: 2535000, Epsilon: 0.17, Avg. Reward per Ep: -17.50
# Episodes: 1502, Steps: 2540000, Epsilon: 0.17, Avg. Reward per Ep: -16.67
# Episodes: 1505, Steps: 2545000, Epsilon: 0.17, Avg. Reward per Ep: -17.67
# Episodes: 1507, Steps: 2550000, Epsilon: 0.17, Avg. Reward per Ep: -16.50
# Episodes: 1510, Steps: 2555000, Epsilon: 0.17, Avg. Reward per Ep: -16.67
# Episodes: 1512, Steps: 2560000, Epsilon: 0.17, Avg. Reward per Ep: -17.50
# Episodes: 1515, Steps: 2565000, Epsilon: 0.17, Avg. Reward per Ep: -17.33
# Episodes: 1517, Steps: 2570000, Epsilon: 0.17, Avg. Reward per Ep: -17.00
# Episodes: 1520, Steps: 2575000, Epsilon: 0.17, Avg. Reward per Ep: -17.67
# Episodes: 1522, Steps: 2580000, Epsilon: 0.17, Avg. Reward per Ep: -18.00
# Episodes: 1525, Steps: 2585000, Epsilon: 0.17, Avg. Reward per Ep: -17.67
# Episodes: 1528, Steps: 2590000, Epsilon: 0.17, Avg. Reward per Ep: -16.67
# Episodes: 1530, Steps: 2595000, Epsilon: 0.17, Avg. Reward per Ep: -17.50
# Episodes: 1532, Steps: 2600000, Epsilon: 0.17, Avg. Reward per Ep: -16.50
# Episodes: 1535, Steps: 2605000, Epsilon: 0.17, Avg. Reward per Ep: -17.00
# Episodes: 1537, Steps: 2610000, Epsilon: 0.17, Avg. Reward per Ep: -18.00
# Episodes: 1540, Steps: 2615000, Epsilon: 0.17, Avg. Reward per Ep: -19.00
# Episodes: 1542, Steps: 2620000, Epsilon: 0.17, Avg. Reward per Ep: -18.00
# Episodes: 1544, Steps: 2625000, Epsilon: 0.17, Avg. Reward per Ep: -15.50
# Episodes: 1546, Steps: 2630000, Epsilon: 0.16, Avg. Reward per Ep: -19.00
# Episodes: 1549, Steps: 2635000, Epsilon: 0.16, Avg. Reward per Ep: -15.00
# Episodes: 1552, Steps: 2640000, Epsilon: 0.16, Avg. Reward per Ep: -17.67
# Episodes: 1554, Steps: 2645000, Epsilon: 0.16, Avg. Reward per Ep: -19.50
# Episodes: 1557, Steps: 2650000, Epsilon: 0.16, Avg. Reward per Ep: -16.00
# Episodes: 1560, Steps: 2655000, Epsilon: 0.16, Avg. Reward per Ep: -18.67
# Episodes: 1562, Steps: 2660000, Epsilon: 0.16, Avg. Reward per Ep: -17.00
# Episodes: 1564, Steps: 2665000, Epsilon: 0.16, Avg. Reward per Ep: -17.50
# Episodes: 1567, Steps: 2670000, Epsilon: 0.16, Avg. Reward per Ep: -17.67
# Episodes: 1569, Steps: 2675000, Epsilon: 0.16, Avg. Reward per Ep: -17.00
# Episodes: 1572, Steps: 2680000, Epsilon: 0.16, Avg. Reward per Ep: -18.00
# Episodes: 1574, Steps: 2685000, Epsilon: 0.16, Avg. Reward per Ep: -16.00
# Episodes: 1576, Steps: 2690000, Epsilon: 0.16, Avg. Reward per Ep: -14.50
# Episodes: 1578, Steps: 2695000, Epsilon: 0.16, Avg. Reward per Ep: -18.50
# Episodes: 1580, Steps: 2700000, Epsilon: 0.16, Avg. Reward per Ep: -15.00
# Episodes: 1582, Steps: 2705000, Epsilon: 0.16, Avg. Reward per Ep: -13.50
# Episodes: 1584, Steps: 2710000, Epsilon: 0.16, Avg. Reward per Ep: -13.50
# Episodes: 1587, Steps: 2715000, Epsilon: 0.16, Avg. Reward per Ep: -18.67
# Episodes: 1589, Steps: 2720000, Epsilon: 0.16, Avg. Reward per Ep: -16.00
# Episodes: 1592, Steps: 2725000, Epsilon: 0.16, Avg. Reward per Ep: -17.67
# Episodes: 1594, Steps: 2730000, Epsilon: 0.16, Avg. Reward per Ep: -15.50
# Episodes: 1597, Steps: 2735000, Epsilon: 0.16, Avg. Reward per Ep: -17.00
# Episodes: 1599, Steps: 2740000, Epsilon: 0.16, Avg. Reward per Ep: -16.00
# Episodes: 1602, Steps: 2745000, Epsilon: 0.16, Avg. Reward per Ep: -18.67
# Episodes: 1604, Steps: 2750000, Epsilon: 0.16, Avg. Reward per Ep: -17.50
# Episodes: 1607, Steps: 2755000, Epsilon: 0.16, Avg. Reward per Ep: -18.67
# Episodes: 1609, Steps: 2760000, Epsilon: 0.16, Avg. Reward per Ep: -17.00
# Episodes: 1611, Steps: 2765000, Epsilon: 0.16, Avg. Reward per Ep: -18.00
# Episodes: 1613, Steps: 2770000, Epsilon: 0.16, Avg. Reward per Ep: -17.00
# Episodes: 1616, Steps: 2775000, Epsilon: 0.16, Avg. Reward per Ep: -16.00
# Episodes: 1618, Steps: 2780000, Epsilon: 0.16, Avg. Reward per Ep: -18.50
# Episodes: 1621, Steps: 2785000, Epsilon: 0.16, Avg. Reward per Ep: -16.33
# Episodes: 1623, Steps: 2790000, Epsilon: 0.16, Avg. Reward per Ep: -19.00
# Episodes: 1626, Steps: 2795000, Epsilon: 0.16, Avg. Reward per Ep: -15.33
# Episodes: 1628, Steps: 2800000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1631, Steps: 2805000, Epsilon: 0.15, Avg. Reward per Ep: -17.33
# Episodes: 1633, Steps: 2810000, Epsilon: 0.15, Avg. Reward per Ep: -19.00
# Episodes: 1636, Steps: 2815000, Epsilon: 0.15, Avg. Reward per Ep: -18.00
# Episodes: 1638, Steps: 2820000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1640, Steps: 2825000, Epsilon: 0.15, Avg. Reward per Ep: -16.50
# Episodes: 1643, Steps: 2830000, Epsilon: 0.15, Avg. Reward per Ep: -18.00
# Episodes: 1645, Steps: 2835000, Epsilon: 0.15, Avg. Reward per Ep: -15.00
# Episodes: 1648, Steps: 2840000, Epsilon: 0.15, Avg. Reward per Ep: -16.00
# Episodes: 1651, Steps: 2845000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1653, Steps: 2850000, Epsilon: 0.15, Avg. Reward per Ep: -15.00
# Episodes: 1656, Steps: 2855000, Epsilon: 0.15, Avg. Reward per Ep: -18.00
# Episodes: 1658, Steps: 2860000, Epsilon: 0.15, Avg. Reward per Ep: -14.50
# Episodes: 1660, Steps: 2865000, Epsilon: 0.15, Avg. Reward per Ep: -17.50
# Episodes: 1662, Steps: 2870000, Epsilon: 0.15, Avg. Reward per Ep: -15.50
# Episodes: 1665, Steps: 2875000, Epsilon: 0.15, Avg. Reward per Ep: -15.33
# Episodes: 1667, Steps: 2880000, Epsilon: 0.15, Avg. Reward per Ep: -19.00
# Episodes: 1669, Steps: 2885000, Epsilon: 0.15, Avg. Reward per Ep: -16.50
# Episodes: 1671, Steps: 2890000, Epsilon: 0.15, Avg. Reward per Ep: -15.00
# Episodes: 1673, Steps: 2895000, Epsilon: 0.15, Avg. Reward per Ep: -18.00
# Episodes: 1676, Steps: 2900000, Epsilon: 0.15, Avg. Reward per Ep: -16.67
# Episodes: 1678, Steps: 2905000, Epsilon: 0.15, Avg. Reward per Ep: -16.00
# Episodes: 1681, Steps: 2910000, Epsilon: 0.15, Avg. Reward per Ep: -18.00
# Episodes: 1683, Steps: 2915000, Epsilon: 0.15, Avg. Reward per Ep: -19.50
# Episodes: 1685, Steps: 2920000, Epsilon: 0.15, Avg. Reward per Ep: -17.50
# Episodes: 1688, Steps: 2925000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1691, Steps: 2930000, Epsilon: 0.15, Avg. Reward per Ep: -18.33
# Episodes: 1693, Steps: 2935000, Epsilon: 0.15, Avg. Reward per Ep: -17.50
# Episodes: 1695, Steps: 2940000, Epsilon: 0.15, Avg. Reward per Ep: -16.00
# Episodes: 1698, Steps: 2945000, Epsilon: 0.15, Avg. Reward per Ep: -17.67
# Episodes: 1700, Steps: 2950000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1703, Steps: 2955000, Epsilon: 0.15, Avg. Reward per Ep: -18.67
# Episodes: 1705, Steps: 2960000, Epsilon: 0.15, Avg. Reward per Ep: -16.00
# Episodes: 1707, Steps: 2965000, Epsilon: 0.15, Avg. Reward per Ep: -16.50
# Episodes: 1710, Steps: 2970000, Epsilon: 0.15, Avg. Reward per Ep: -17.33
# Episodes: 1713, Steps: 2975000, Epsilon: 0.15, Avg. Reward per Ep: -19.00
# Episodes: 1715, Steps: 2980000, Epsilon: 0.15, Avg. Reward per Ep: -18.50
# Episodes: 1717, Steps: 2985000, Epsilon: 0.15, Avg. Reward per Ep: -18.50
# Episodes: 1719, Steps: 2990000, Epsilon: 0.15, Avg. Reward per Ep: -17.00
# Episodes: 1722, Steps: 2995000, Epsilon: 0.15, Avg. Reward per Ep: -14.33
# Episodes: 1724, Steps: 3000000, Epsilon: 0.14, Avg. Reward per Ep: -17.00
# Episodes: 1726, Steps: 3005000, Epsilon: 0.14, Avg. Reward per Ep: -18.50
# Episodes: 1729, Steps: 3010000, Epsilon: 0.14, Avg. Reward per Ep: -15.67
# Episodes: 1732, Steps: 3015000, Epsilon: 0.14, Avg. Reward per Ep: -17.00
# Episodes: 1734, Steps: 3020000, Epsilon: 0.14, Avg. Reward per Ep: -17.00
# Episodes: 1737, Steps: 3025000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1739, Steps: 3030000, Epsilon: 0.14, Avg. Reward per Ep: -17.50
# Episodes: 1742, Steps: 3035000, Epsilon: 0.14, Avg. Reward per Ep: -15.33
# Episodes: 1745, Steps: 3040000, Epsilon: 0.14, Avg. Reward per Ep: -18.00
# Episodes: 1747, Steps: 3045000, Epsilon: 0.14, Avg. Reward per Ep: -18.00
# Episodes: 1750, Steps: 3050000, Epsilon: 0.14, Avg. Reward per Ep: -18.33
# Episodes: 1752, Steps: 3055000, Epsilon: 0.14, Avg. Reward per Ep: -18.00
# Episodes: 1755, Steps: 3060000, Epsilon: 0.14, Avg. Reward per Ep: -16.33
# Episodes: 1758, Steps: 3065000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1760, Steps: 3070000, Epsilon: 0.14, Avg. Reward per Ep: -15.00
# Episodes: 1763, Steps: 3075000, Epsilon: 0.14, Avg. Reward per Ep: -18.33
# Episodes: 1765, Steps: 3080000, Epsilon: 0.14, Avg. Reward per Ep: -17.00
# Episodes: 1768, Steps: 3085000, Epsilon: 0.14, Avg. Reward per Ep: -18.67
# Episodes: 1771, Steps: 3090000, Epsilon: 0.14, Avg. Reward per Ep: -16.33
# Episodes: 1773, Steps: 3095000, Epsilon: 0.14, Avg. Reward per Ep: -16.50
# Episodes: 1775, Steps: 3100000, Epsilon: 0.14, Avg. Reward per Ep: -16.50
# Episodes: 1778, Steps: 3105000, Epsilon: 0.14, Avg. Reward per Ep: -16.67
# Episodes: 1781, Steps: 3110000, Epsilon: 0.14, Avg. Reward per Ep: -19.00
# Episodes: 1783, Steps: 3115000, Epsilon: 0.14, Avg. Reward per Ep: -19.00
# Episodes: 1787, Steps: 3120000, Epsilon: 0.14, Avg. Reward per Ep: -18.50
# Episodes: 1790, Steps: 3125000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1793, Steps: 3130000, Epsilon: 0.14, Avg. Reward per Ep: -17.00
# Episodes: 1796, Steps: 3135000, Epsilon: 0.14, Avg. Reward per Ep: -20.00
# Episodes: 1798, Steps: 3140000, Epsilon: 0.14, Avg. Reward per Ep: -16.50
# Episodes: 1801, Steps: 3145000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1804, Steps: 3150000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1807, Steps: 3155000, Epsilon: 0.14, Avg. Reward per Ep: -18.67
# Episodes: 1810, Steps: 3160000, Epsilon: 0.14, Avg. Reward per Ep: -18.00
# Episodes: 1812, Steps: 3165000, Epsilon: 0.14, Avg. Reward per Ep: -18.50
# Episodes: 1815, Steps: 3170000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1817, Steps: 3175000, Epsilon: 0.14, Avg. Reward per Ep: -16.00
# Episodes: 1820, Steps: 3180000, Epsilon: 0.14, Avg. Reward per Ep: -20.00
# Episodes: 1823, Steps: 3185000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 1825, Steps: 3190000, Epsilon: 0.14, Avg. Reward per Ep: -18.00
# Episodes: 1829, Steps: 3195000, Epsilon: 0.14, Avg. Reward per Ep: -19.75
# Episodes: 1831, Steps: 3200000, Epsilon: 0.14, Avg. Reward per Ep: -18.50
# Episodes: 1834, Steps: 3205000, Epsilon: 0.14, Avg. Reward per Ep: -17.33
# Episodes: 1837, Steps: 3210000, Epsilon: 0.14, Avg. Reward per Ep: -17.33
# Episodes: 1840, Steps: 3215000, Epsilon: 0.14, Avg. Reward per Ep: -18.33
# Episodes: 1842, Steps: 3220000, Epsilon: 0.14, Avg. Reward per Ep: -16.00
# Episodes: 1844, Steps: 3225000, Epsilon: 0.14, Avg. Reward per Ep: -16.00
# Episodes: 1847, Steps: 3230000, Epsilon: 0.14, Avg. Reward per Ep: -16.67
# Episodes: 1849, Steps: 3235000, Epsilon: 0.14, Avg. Reward per Ep: -16.00
# Episodes: 1852, Steps: 3240000, Epsilon: 0.14, Avg. Reward per Ep: -16.00
# Episodes: 1854, Steps: 3245000, Epsilon: 0.14, Avg. Reward per Ep: -17.50
# Episodes: 1857, Steps: 3250000, Epsilon: 0.13, Avg. Reward per Ep: -18.67
# Episodes: 1860, Steps: 3255000, Epsilon: 0.13, Avg. Reward per Ep: -17.33
# Episodes: 1862, Steps: 3260000, Epsilon: 0.13, Avg. Reward per Ep: -15.50
# Episodes: 1865, Steps: 3265000, Epsilon: 0.13, Avg. Reward per Ep: -19.33
# Episodes: 1867, Steps: 3270000, Epsilon: 0.13, Avg. Reward per Ep: -16.50
# Episodes: 1870, Steps: 3275000, Epsilon: 0.13, Avg. Reward per Ep: -16.67
# Episodes: 1872, Steps: 3280000, Epsilon: 0.13, Avg. Reward per Ep: -17.50
# ...
# Episodes: 2674, Steps: 4885000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2677, Steps: 4890000, Epsilon: 0.11, Avg. Reward per Ep: -16.33
# Episodes: 2679, Steps: 4895000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2682, Steps: 4900000, Epsilon: 0.11, Avg. Reward per Ep: -16.33
# Episodes: 2684, Steps: 4905000, Epsilon: 0.11, Avg. Reward per Ep: -13.00
# Episodes: 2686, Steps: 4910000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2688, Steps: 4915000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2690, Steps: 4920000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2692, Steps: 4925000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2695, Steps: 4930000, Epsilon: 0.11, Avg. Reward per Ep: -15.00
# Episodes: 2697, Steps: 4935000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2699, Steps: 4940000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2701, Steps: 4945000, Epsilon: 0.11, Avg. Reward per Ep: -14.00
# Episodes: 2703, Steps: 4950000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2705, Steps: 4955000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2708, Steps: 4960000, Epsilon: 0.11, Avg. Reward per Ep: -16.67
# Episodes: 2710, Steps: 4965000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2712, Steps: 4970000, Epsilon: 0.11, Avg. Reward per Ep: -15.50
# Episodes: 2715, Steps: 4975000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2717, Steps: 4980000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2719, Steps: 4985000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2722, Steps: 4990000, Epsilon: 0.11, Avg. Reward per Ep: -16.33
# Episodes: 2724, Steps: 4995000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2726, Steps: 5000000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2729, Steps: 5005000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2731, Steps: 5010000, Epsilon: 0.11, Avg. Reward per Ep: -14.00
# Episodes: 2733, Steps: 5015000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2735, Steps: 5020000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2737, Steps: 5025000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2740, Steps: 5030000, Epsilon: 0.11, Avg. Reward per Ep: -14.67
# Episodes: 2742, Steps: 5035000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2745, Steps: 5040000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2747, Steps: 5045000, Epsilon: 0.11, Avg. Reward per Ep: -17.50
# Episodes: 2749, Steps: 5050000, Epsilon: 0.11, Avg. Reward per Ep: -15.00
# Episodes: 2752, Steps: 5055000, Epsilon: 0.11, Avg. Reward per Ep: -16.33
# Episodes: 2754, Steps: 5060000, Epsilon: 0.11, Avg. Reward per Ep: -15.00
# Episodes: 2757, Steps: 5065000, Epsilon: 0.11, Avg. Reward per Ep: -15.67
# Episodes: 2759, Steps: 5070000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2761, Steps: 5075000, Epsilon: 0.11, Avg. Reward per Ep: -15.00
# Episodes: 2763, Steps: 5080000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2765, Steps: 5085000, Epsilon: 0.11, Avg. Reward per Ep: -15.00
# Episodes: 2767, Steps: 5090000, Epsilon: 0.11, Avg. Reward per Ep: -16.50
# Episodes: 2769, Steps: 5095000, Epsilon: 0.11, Avg. Reward per Ep: -17.50
# Episodes: 2772, Steps: 5100000, Epsilon: 0.11, Avg. Reward per Ep: -17.67
# Episodes: 2775, Steps: 5105000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2777, Steps: 5110000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2779, Steps: 5115000, Epsilon: 0.11, Avg. Reward per Ep: -18.00
# Episodes: 2782, Steps: 5120000, Epsilon: 0.11, Avg. Reward per Ep: -16.33
# Episodes: 2784, Steps: 5125000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2786, Steps: 5130000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2788, Steps: 5135000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2791, Steps: 5140000, Epsilon: 0.11, Avg. Reward per Ep: -18.33
# Episodes: 2793, Steps: 5145000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2795, Steps: 5150000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2798, Steps: 5155000, Epsilon: 0.11, Avg. Reward per Ep: -15.33
# Episodes: 2800, Steps: 5160000, Epsilon: 0.11, Avg. Reward per Ep: -18.50
# Episodes: 2802, Steps: 5165000, Epsilon: 0.11, Avg. Reward per Ep: -13.00
# Episodes: 2804, Steps: 5170000, Epsilon: 0.11, Avg. Reward per Ep: -17.00
# Episodes: 2806, Steps: 5175000, Epsilon: 0.11, Avg. Reward per Ep: -12.50
# Episodes: 2808, Steps: 5180000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2810, Steps: 5185000, Epsilon: 0.11, Avg. Reward per Ep: -16.00
# Episodes: 2812, Steps: 5190000, Epsilon: 0.11, Avg. Reward per Ep: -14.50
# Episodes: 2814, Steps: 5195000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2817, Steps: 5200000, Epsilon: 0.10, Avg. Reward per Ep: -15.67
# Episodes: 2819, Steps: 5205000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 2821, Steps: 5210000, Epsilon: 0.10, Avg. Reward per Ep: -12.00
# Episodes: 2823, Steps: 5215000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2825, Steps: 5220000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2827, Steps: 5225000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2830, Steps: 5230000, Epsilon: 0.10, Avg. Reward per Ep: -15.67
# Episodes: 2832, Steps: 5235000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2835, Steps: 5240000, Epsilon: 0.10, Avg. Reward per Ep: -16.33
# Episodes: 2839, Steps: 5245000, Epsilon: 0.10, Avg. Reward per Ep: -19.25
# Episodes: 2842, Steps: 5250000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2845, Steps: 5255000, Epsilon: 0.10, Avg. Reward per Ep: -18.33
# Episodes: 2848, Steps: 5260000, Epsilon: 0.10, Avg. Reward per Ep: -18.67
# Episodes: 2851, Steps: 5265000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2854, Steps: 5270000, Epsilon: 0.10, Avg. Reward per Ep: -18.67
# Episodes: 2856, Steps: 5275000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2860, Steps: 5280000, Epsilon: 0.10, Avg. Reward per Ep: -18.75
# Episodes: 2862, Steps: 5285000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 2864, Steps: 5290000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2866, Steps: 5295000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# Episodes: 2869, Steps: 5300000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2871, Steps: 5305000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 2874, Steps: 5310000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2876, Steps: 5315000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2878, Steps: 5320000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 2880, Steps: 5325000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 2883, Steps: 5330000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 2885, Steps: 5335000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2887, Steps: 5340000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 2890, Steps: 5345000, Epsilon: 0.10, Avg. Reward per Ep: -15.33
# Episodes: 2892, Steps: 5350000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2895, Steps: 5355000, Epsilon: 0.10, Avg. Reward per Ep: -17.33
# Episodes: 2897, Steps: 5360000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2899, Steps: 5365000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2902, Steps: 5370000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2905, Steps: 5375000, Epsilon: 0.10, Avg. Reward per Ep: -19.00
# Episodes: 2907, Steps: 5380000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2909, Steps: 5385000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2912, Steps: 5390000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2914, Steps: 5395000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2916, Steps: 5400000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2919, Steps: 5405000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 2921, Steps: 5410000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 2923, Steps: 5415000, Epsilon: 0.10, Avg. Reward per Ep: -13.50
# Episodes: 2925, Steps: 5420000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2928, Steps: 5425000, Epsilon: 0.10, Avg. Reward per Ep: -16.67
# Episodes: 2931, Steps: 5430000, Epsilon: 0.10, Avg. Reward per Ep: -18.67
# Episodes: 2933, Steps: 5435000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 2935, Steps: 5440000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# Episodes: 2938, Steps: 5445000, Epsilon: 0.10, Avg. Reward per Ep: -17.33
# Episodes: 2941, Steps: 5450000, Epsilon: 0.10, Avg. Reward per Ep: -16.67
# Episodes: 2943, Steps: 5455000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 2945, Steps: 5460000, Epsilon: 0.10, Avg. Reward per Ep: -13.50
# Episodes: 2947, Steps: 5465000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# Episodes: 2949, Steps: 5470000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 2952, Steps: 5475000, Epsilon: 0.10, Avg. Reward per Ep: -18.33
# Episodes: 2954, Steps: 5480000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 2957, Steps: 5485000, Epsilon: 0.10, Avg. Reward per Ep: -15.67
# Episodes: 2960, Steps: 5490000, Epsilon: 0.10, Avg. Reward per Ep: -18.33
# Episodes: 2962, Steps: 5495000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2965, Steps: 5500000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2967, Steps: 5505000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 2969, Steps: 5510000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 2972, Steps: 5515000, Epsilon: 0.10, Avg. Reward per Ep: -16.33
# Episodes: 2975, Steps: 5520000, Epsilon: 0.10, Avg. Reward per Ep: -17.33
# Episodes: 2978, Steps: 5525000, Epsilon: 0.10, Avg. Reward per Ep: -16.67
# Episodes: 2980, Steps: 5530000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 2982, Steps: 5535000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2984, Steps: 5540000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 2986, Steps: 5545000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 2988, Steps: 5550000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 2991, Steps: 5555000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2993, Steps: 5560000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2995, Steps: 5565000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 2998, Steps: 5570000, Epsilon: 0.10, Avg. Reward per Ep: -15.33
# Episodes: 3000, Steps: 5575000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 3002, Steps: 5580000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3004, Steps: 5585000, Epsilon: 0.10, Avg. Reward per Ep: -13.50
# Episodes: 3007, Steps: 5590000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3009, Steps: 5595000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3011, Steps: 5600000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# Episodes: 3014, Steps: 5605000, Epsilon: 0.10, Avg. Reward per Ep: -13.00
# Episodes: 3016, Steps: 5610000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3018, Steps: 5615000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 3020, Steps: 5620000, Epsilon: 0.10, Avg. Reward per Ep: -13.00
# Episodes: 3022, Steps: 5625000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3025, Steps: 5630000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3026, Steps: 5635000, Epsilon: 0.10, Avg. Reward per Ep: -13.00
# Episodes: 3029, Steps: 5640000, Epsilon: 0.10, Avg. Reward per Ep: -14.67
# Episodes: 3031, Steps: 5645000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3033, Steps: 5650000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3035, Steps: 5655000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3037, Steps: 5660000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 3040, Steps: 5665000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 3042, Steps: 5670000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 3044, Steps: 5675000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 3046, Steps: 5680000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 3049, Steps: 5685000, Epsilon: 0.10, Avg. Reward per Ep: -19.00
# Episodes: 3051, Steps: 5690000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3053, Steps: 5695000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 3055, Steps: 5700000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3058, Steps: 5705000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 3060, Steps: 5710000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3062, Steps: 5715000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 3064, Steps: 5720000, Epsilon: 0.10, Avg. Reward per Ep: -14.50
# Episodes: 3067, Steps: 5725000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3069, Steps: 5730000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3072, Steps: 5735000, Epsilon: 0.10, Avg. Reward per Ep: -16.33
# Episodes: 3074, Steps: 5740000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3076, Steps: 5745000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3078, Steps: 5750000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3080, Steps: 5755000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3082, Steps: 5760000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3085, Steps: 5765000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3086, Steps: 5770000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3089, Steps: 5775000, Epsilon: 0.10, Avg. Reward per Ep: -15.00
# Episodes: 3091, Steps: 5780000, Epsilon: 0.10, Avg. Reward per Ep: -18.00
# Episodes: 3094, Steps: 5785000, Epsilon: 0.10, Avg. Reward per Ep: -15.33
# Episodes: 3096, Steps: 5790000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 3099, Steps: 5795000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3101, Steps: 5800000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# Episodes: 3103, Steps: 5805000, Epsilon: 0.10, Avg. Reward per Ep: -15.50
# Episodes: 3106, Steps: 5810000, Epsilon: 0.10, Avg. Reward per Ep: -17.67
# Episodes: 3109, Steps: 5815000, Epsilon: 0.10, Avg. Reward per Ep: -15.67
# Episodes: 3111, Steps: 5820000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3113, Steps: 5825000, Epsilon: 0.10, Avg. Reward per Ep: -16.50
# Episodes: 3116, Steps: 5830000, Epsilon: 0.10, Avg. Reward per Ep: -14.67
# Episodes: 3119, Steps: 5835000, Epsilon: 0.10, Avg. Reward per Ep: -17.00
# Episodes: 3121, Steps: 5840000, Epsilon: 0.10, Avg. Reward per Ep: -14.00
# Episodes: 3123, Steps: 5845000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3125, Steps: 5850000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3128, Steps: 5855000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3130, Steps: 5860000, Epsilon: 0.10, Avg. Reward per Ep: -12.50
# Episodes: 3132, Steps: 5865000, Epsilon: 0.10, Avg. Reward per Ep: -13.00
# Episodes: 3134, Steps: 5870000, Epsilon: 0.10, Avg. Reward per Ep: -16.00
# Episodes: 3137, Steps: 5875000, Epsilon: 0.10, Avg. Reward per Ep: -13.67
# Episodes: 3139, Steps: 5880000, Epsilon: 0.10, Avg. Reward per Ep: -12.00
# Episodes: 3141, Steps: 5885000, Epsilon: 0.10, Avg. Reward per Ep: -17.50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3d92c9b1ff97> in <module>()
# ----> 1 agent.train()
#
# <ipython-input-8-20a8def4dd9c> in train(self)
#     162                 #update model parameters
#     163                 if mem.is_available() and self.steps % self.update_freq == 0:
# --> 164                     loss = self.optimize()
#     165
#     166                 #increase number of steps
#
# <ipython-input-8-20a8def4dd9c> in optimize(self)
#     264
#     265         #update parameters
# --> 266         self.optimizer.step()
#     267
#     268         return loss.item()
#
# ~/.conda/envs/pytorch04/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      90
#      91                 # Decay the first and second moment running average coefficient
# ---> 92                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      93                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      94                 if amsgrad:
#
# KeyboardInterrupt:
