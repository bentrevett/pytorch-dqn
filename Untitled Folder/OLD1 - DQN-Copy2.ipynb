# %% [markdown]
# - https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf
# - https://ai.intel.com/demystifying-deep-reinforcement-learning/
# - https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/
#
# - https://github.com/AndersonJo/dqn-pytorch/blob/master/dqn.py
# - https://github.com/hengyuan-hu/rainbow
# - https://github.com/transedward/pytorch-dqn

# %%
import matplotlib.pyplot as plt
import gym
import cv2
import random
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
from collections import namedtuple
import copy

# %%
SEED = 1234
CAPACITY = 10_000
BATCH_SIZE = 32
GAME = 'PongNoFrameskip-v4'
N_ACTIONS = gym.make(GAME).action_space.n
PHI_LENGTH = 4
UPDATE_FREQ = 1
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_STEPS = 30_000
GAMMA = 0.99
TARGET_UPDATE = 1_000
PRINT_UPDATE = 5_000

# %%
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class ReplayMemory:
    def __init__(self, capacity, batch_size):
        """
        Replay memory that holds examples in the form of (s, a, r, s')
        
        args:
            capacity (int): the size of the memory
            batch_size (int): size of batches used for training model
        """
        
        self.batch_size = batch_size
        self.capacity = capacity
        self.memory = deque(maxlen=self.capacity)
        self.Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state'))
        self._available = False

    def put(self, state, action, reward, next_state):
        """
        Places an (s, a, r, s') example in the memory
        
        args:
            state (np.array): 
            action (list[int]):
            reward (list[int]):
            next_state (np.array or None):
        """
        
        state = torch.FloatTensor(state)
        action = torch.LongTensor([action])
        reward = torch.FloatTensor([reward])
        if next_state is not None:
            next_state = torch.FloatTensor(next_state)
        transition = self.Transition(state=state, action=action, reward=reward, next_state=next_state)
        self.memory.append(transition)

    def sample(self):
        """
        Gets a random sample of n = batch_size examples from the memory
            
        returns:
            Transitions (namedtuple): a tuple of (s, a, r, s')
        """
        
        transitions = random.sample(self.memory, self.batch_size)
        return self.Transition(*(zip(*transitions)))

    def size(self):
        """
        Returns the length of the memory
        
        returns:
            length (int): number of examples in the memory
        """
        return len(self.memory)

    def is_available(self):
        """
        Returns True if we have enough examples within the memory
        
        returns:
            available (bool): True if we have at least n = batch_size examples in the memory
        """
        if self._available:
            return True

        if len(self.memory) > self.batch_size:
            self._available = True
        return self._available

# %%
class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """Sample initial states by taking random number of no-ops on reset.
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1) 
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)
    
class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip       = skip

    def reset(self):
        return self.env.reset()

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs): 
        return self.env.reset(**kwargs)
    
class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
        """Take action on reset for environments that are fixed until firing."""
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done  = True

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert sometimes we stay in lives == 0 condtion for a few frames
            # so its important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self, **kwargs):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs
    
class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env):
        """Warp frames to 84x84 as done in the Nature paper and later work."""
        gym.ObservationWrapper.__init__(self, env)
        self.width = 84
        self.height = 84
        self.observation_space = gym.spaces.Box(low=0, high=255,
            shape=(self.height, self.width, 1), dtype=np.uint8)

    def observation(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.width, self.height), interpolation=cv2.INTER_AREA)
        return frame[:, :, None]
    
class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)

class LazyFrames(object):
    def __init__(self, frames):
        """This object ensures that common frames between the observations are only stored once.
        It exists purely to optimize memory usage which can be huge for DQN's 1M frames replay
        buffers.
        This object should only be converted to numpy array before being passed to the model.
        You'd not believe how complex the previous solution was."""
        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=2)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]    
    
class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.
        Returns lazy array, which is much more memory efficient.
        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(shp[0], shp[1], shp[2] * k), dtype=np.uint8)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))

class ImageToPyTorch(gym.ObservationWrapper):
    """
    Image shape to num_channels x weight x height
    """
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], old_shape[0], old_shape[1]), dtype=np.uint8)

    def observation(self, observation):
        return np.swapaxes(observation, 2, 0)
    
def wrap_pytorch(env):
    return ImageToPyTorch(env)
    
def make_atari(env_id):
    env = gym.make(env_id)
    assert 'NoFrameskip' in env.spec.id
    env = NoopResetEnv(env, noop_max=30)
    env = MaxAndSkipEnv(env, skip=4)
    return env

def wrap_deepmind(env, episode_life=True, clip_rewards=True, frame_stack=False, scale=False):
    """Configure environment for DeepMind-style Atari.
    """
    if episode_life:
        env = EpisodicLifeEnv(env)
    if 'FIRE' in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)
    env = WarpFrame(env)
    if scale:
        env = ScaledFloatFrame(env)
    if clip_rewards:
        env = ClipRewardEnv(env)
    if frame_stack:
        env = FrameStack(env, 4)
    return env

# %%
class DQN(nn.Module):

    def __init__(self, n_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(7*7*64, 512)
        self.fc2 = nn.Linear(512, n_actions) #actions from from env.action_space.n

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc1(x.view(x.size(0), -1))) #flattens the (N, C, H, W) to (N, C*H*W)
        return self.fc2(x)

# %%
class Agent:
    def __init__(self, env, mem, model, phi_length, update_freq, e_start, e_end, e_steps, gamma, target_update, print_update):
        """
        An agent class that handles training the model

        args:
            mem (ReplayMemory): ReplayMemory object
            env (Environment): Environment object
            model (nn.Module): PyTorch model
            phi_length (int): number of observations to stack to make a state
            frame_skip (int): we only use every n = frame_skip observations to make a state
            e_start (int): initial value of epsilon
            e_end (int): minimum value of epsilon
            e_steps (int): number of steps for epsilon to go from e_start to e_end
            gamma (float): decay rate of rewards
            target_update (int): after how many steps (frames) to update target model
            print_update (int): after how many steps (frames) to print summary of performance
            
        """
        self.env = env
        self.mem = mem
        self.model = model
        self.phi_length = phi_length
        self.update_freq = update_freq
        self.e_start = e_start
        self.e_end = e_end
        self.e_steps = e_steps
        self.gamma = gamma
        self.target_update = target_update
        self.print_update = print_update
        
        self.steps = 0 #number of steps taken
        self.episodes = 0 #number of episodes
        self.obs_buffer = deque(maxlen=phi_length) #for holding observations to be turned into states
        
        #put model on gpu if available
        self.model = model.to(device)
        
        #create target model
        self.target = copy.deepcopy(self.model)
        self.target.train()
    
        #create optimizer
        #self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025, alpha=0.95, momentum=0.95)
        self.optimizer = optim.Adam(self.model.parameters(), lr=1e-4)
        
    def get_epsilon(self):
        """
        Calculates the value of epsilon from the current number of frames
        
        returns:
            epsilon (int): the probability of doing a random action
        """
        epsilon = self.e_end + (self.e_start - self.e_end) * math.exp(-1. * self.steps / self.e_steps)
        return epsilon
        
    def get_action(self, state):
        """
        Selects action to perform, with probability = epsilon chooses a random action,
        else chooses the best predicted action of the model
        
        args:
            state (np.array): input state to the model
            
        returns:
            action (int): the index of the action 
        """
    
        #get value of epsilon
        epsilon = self.get_epsilon()
        
        #with probablity of epsilon, pick a random action
        if random.random() < epsilon:
            action = self.env.action_space.sample()
        
        else:
            #with probability of (1 - epsilon) pick predicted value
            with torch.no_grad():
                state = torch.FloatTensor(state).unsqueeze(0).to(device) #convert to tensor, reshape and add to gpu
                Qsa = self.model(state) #pass state through model to get Qa
                action = Qsa.max(1)[1].item() #action is max Qa value
                
        #make sure the value is an integer
        assert isinstance(action, int)
            
        return action
        
    def train(self):
        
        training_done = False
        reward_per_episode = []
        rewards_all_episodes = []
        
        while not training_done:
            
            episode_done = False
            episode_reward = 0
            episode_steps = 0
            
            #get initial state
            state = self.env.reset()
            
            while not episode_done:
                                
                #get action
                action = self.get_action(state)
                               
                #apply action while skipping frames
                next_state, reward, episode_done, info = self.env.step(action)

                #sum rewards
                episode_reward += reward
       
                #add to memory, for terminal states, set next_state to None
                if episode_done:
                    mem.put(state, action, reward, None)
                else:
                    mem.put(state, action, reward, next_state)
                    
                #make new state the old next_state
                state = next_state
                                
                #increase number of steps
                self.steps += 1
                episode_steps += 1 
            
                #update model parameters
                if mem.is_available() and self.steps % self.update_freq == 0 and self.steps > 10_000:
                    loss = self.optimize()
            
                if self.steps % (self.target_update*self.update_freq) == 0 and self.steps > 10_000:
                    self.target.load_state_dict(self.model.state_dict())
            
                if self.steps % self.print_update == 0:
                    avg_reward_per_episode = np.mean(reward_per_episode)
                    #rewards_all_episodes.extend(reward_per_episode)
                    reward_per_episode = []
                    print(f'Episodes: {self.episodes}, Steps: {self.steps}, Epsilon: {self.get_epsilon():.2f}, Avg. Reward per Ep: {avg_reward_per_episode:.2f}')

            #increase number of episodes
            self.episodes += 1
            reward_per_episode.append(episode_reward)
                            
    
    def optimize(self):
        """
        Update model parameters
        """
        
        #get a batch
        transitions = mem.sample()
        
        #need to set the Q value of terminal states to 0
        #this mask will be 1 for non-terminal next_states and 0 for terminal next_states
        non_terminal_mask = torch.ByteTensor(list(map(lambda ns: ns is not None, transitions.next_state)))
        
        #this will be 1 for terminal next_states, and 0 for non-terminal next states
        terminal_mask = 1 - non_terminal_mask
        
        #state_batch = (N*C,H,W), where N is batch_size, C is phi_length, H and W are processed obs size
        state_batch = torch.cat(transitions.state).to(device)
        
        #action_batch = (N, 1)
        action_batch = torch.cat(transitions.action).unsqueeze(1).to(device)
        
        #reward_batch = (N, 1)
        reward_batch = torch.cat(transitions.reward).unsqueeze(1).to(device)
        
        #next_state_batch = (V*C,H,W), where V is non_terminal next_state
        non_terminal_next_state_batch = torch.cat([ns for ns in transitions.next_state if ns is not None]).to(device)
        
        #reshape to (N,C,H,W)
        state_batch = state_batch.view(mem.batch_size, self.phi_length, 84, 84)
        
        #reshape to (V,C,H,W)
        non_terminal_next_state_batch = non_terminal_next_state_batch.view(-1, self.phi_length, 84, 84)
        
        #get predicted Q values from model
        Q_pred = self.model(state_batch)
        
        #get Q values of action taken, shape (N,1)
        Q_vals = Q_pred.gather(1, action_batch)
          
        with torch.no_grad():
            #get Q values from target model  
            target_pred = self.target(non_terminal_next_state_batch)

            #tensor for placing target values
            target_vals = torch.zeros(mem.batch_size, 1).to(device) 
            
            #fill in target values for non_terminal states
            #the terminal states will stay initialized as zeros
            target_vals[non_terminal_mask] = reward_batch[non_terminal_mask] + target_pred.max(1)[0].unsqueeze(1) * self.gamma
            target_vals[terminal_mask] = reward_batch[terminal_mask]

            
        #calculate loss between Q values and target values
        loss = F.smooth_l1_loss(Q_vals, target_vals.detach())
            
        #zero gradients
        self.optimizer.zero_grad()
        
        #calculate gradients 
        loss.backward()
        
        #clamp gradients
        for p in self.model.parameters():
            p.grad.data.clamp_(-1, 1)
            
        #update parameters
        self.optimizer.step()
        
        return loss.item()

# %%
env = make_atari(GAME)
env = wrap_deepmind(env, frame_stack=True)
env = wrap_pytorch(env)
env.seed(SEED)

mem = ReplayMemory(CAPACITY, BATCH_SIZE)
model = DQN(N_ACTIONS)
agent = Agent(env, mem, model, PHI_LENGTH, UPDATE_FREQ, EPSILON_START, EPSILON_END, EPSILON_STEPS, GAMMA, TARGET_UPDATE, PRINT_UPDATE)

# %%
s, ns = agent.train()
# Out:
# Episodes: 5, Steps: 5000, Epsilon: 0.85, Avg. Reward per Ep: -20.40
# Episodes: 10, Steps: 10000, Epsilon: 0.72, Avg. Reward per Ep: -20.00
# Episodes: 16, Steps: 15000, Epsilon: 0.61, Avg. Reward per Ep: -20.33
# Episodes: 21, Steps: 20000, Epsilon: 0.52, Avg. Reward per Ep: -20.40
# Episodes: 27, Steps: 25000, Epsilon: 0.44, Avg. Reward per Ep: -20.17
# Episodes: 32, Steps: 30000, Epsilon: 0.37, Avg. Reward per Ep: -20.00
# Episodes: 36, Steps: 35000, Epsilon: 0.32, Avg. Reward per Ep: -19.50
# Episodes: 41, Steps: 40000, Epsilon: 0.27, Avg. Reward per Ep: -19.60
# Episodes: 44, Steps: 45000, Epsilon: 0.23, Avg. Reward per Ep: -18.67
# Episodes: 48, Steps: 50000, Epsilon: 0.20, Avg. Reward per Ep: -18.50
# Episodes: 51, Steps: 55000, Epsilon: 0.17, Avg. Reward per Ep: -17.33
# Episodes: 54, Steps: 60000, Epsilon: 0.14, Avg. Reward per Ep: -17.67
# Episodes: 58, Steps: 65000, Epsilon: 0.12, Avg. Reward per Ep: -17.25
# Episodes: 61, Steps: 70000, Epsilon: 0.11, Avg. Reward per Ep: -15.67
# Episodes: 63, Steps: 75000, Epsilon: 0.09, Avg. Reward per Ep: -15.50
# Episodes: 66, Steps: 80000, Epsilon: 0.08, Avg. Reward per Ep: -14.00
# Episodes: 68, Steps: 85000, Epsilon: 0.07, Avg. Reward per Ep: -13.50
# Episodes: 71, Steps: 90000, Epsilon: 0.06, Avg. Reward per Ep: -12.33
# Episodes: 73, Steps: 95000, Epsilon: 0.05, Avg. Reward per Ep: -12.00
# Episodes: 76, Steps: 100000, Epsilon: 0.05, Avg. Reward per Ep: -13.67
# Episodes: 77, Steps: 105000, Epsilon: 0.04, Avg. Reward per Ep: -4.00
# Episodes: 79, Steps: 110000, Epsilon: 0.04, Avg. Reward per Ep: -5.00
# Episodes: 82, Steps: 115000, Epsilon: 0.03, Avg. Reward per Ep: -6.33
# Episodes: 84, Steps: 120000, Epsilon: 0.03, Avg. Reward per Ep: -10.00
# Episodes: 86, Steps: 125000, Epsilon: 0.03, Avg. Reward per Ep: -8.50
# Episodes: 87, Steps: 130000, Epsilon: 0.02, Avg. Reward per Ep: -7.00
# Episodes: 89, Steps: 135000, Epsilon: 0.02, Avg. Reward per Ep: 2.50
# Episodes: 91, Steps: 140000, Epsilon: 0.02, Avg. Reward per Ep: 1.00
# Episodes: 92, Steps: 145000, Epsilon: 0.02, Avg. Reward per Ep: 2.00
# Episodes: 95, Steps: 150000, Epsilon: 0.02, Avg. Reward per Ep: -3.33
# Episodes: 97, Steps: 155000, Epsilon: 0.02, Avg. Reward per Ep: -5.50
# Episodes: 98, Steps: 160000, Epsilon: 0.01, Avg. Reward per Ep: 1.00
# Episodes: 100, Steps: 165000, Epsilon: 0.01, Avg. Reward per Ep: 8.50
# Episodes: 102, Steps: 170000, Epsilon: 0.01, Avg. Reward per Ep: 8.50
# Episodes: 104, Steps: 175000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 107, Steps: 180000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 109, Steps: 185000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 112, Steps: 190000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 114, Steps: 195000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 117, Steps: 200000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 119, Steps: 205000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 122, Steps: 210000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 124, Steps: 215000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 127, Steps: 220000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 129, Steps: 225000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 132, Steps: 230000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 134, Steps: 235000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 136, Steps: 240000, Epsilon: 0.01, Avg. Reward per Ep: 7.50
# Episodes: 139, Steps: 245000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 141, Steps: 250000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 144, Steps: 255000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 147, Steps: 260000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 149, Steps: 265000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 152, Steps: 270000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 154, Steps: 275000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 157, Steps: 280000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 159, Steps: 285000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 162, Steps: 290000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 164, Steps: 295000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 167, Steps: 300000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 169, Steps: 305000, Epsilon: 0.01, Avg. Reward per Ep: 9.50
# Episodes: 172, Steps: 310000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 174, Steps: 315000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 177, Steps: 320000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 180, Steps: 325000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 182, Steps: 330000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 185, Steps: 335000, Epsilon: 0.01, Avg. Reward per Ep: 11.67
# Episodes: 187, Steps: 340000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 190, Steps: 345000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 193, Steps: 350000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 195, Steps: 355000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 198, Steps: 360000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 200, Steps: 365000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 203, Steps: 370000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 206, Steps: 375000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 209, Steps: 380000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 211, Steps: 385000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 214, Steps: 390000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 217, Steps: 395000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 220, Steps: 400000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 222, Steps: 405000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 225, Steps: 410000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 227, Steps: 415000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 230, Steps: 420000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 233, Steps: 425000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 236, Steps: 430000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 239, Steps: 435000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 241, Steps: 440000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 244, Steps: 445000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 247, Steps: 450000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 250, Steps: 455000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 252, Steps: 460000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 255, Steps: 465000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 257, Steps: 470000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 260, Steps: 475000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 263, Steps: 480000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 266, Steps: 485000, Epsilon: 0.01, Avg. Reward per Ep: 5.00
# Episodes: 269, Steps: 490000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 271, Steps: 495000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 273, Steps: 500000, Epsilon: 0.01, Avg. Reward per Ep: 2.00
# Episodes: 276, Steps: 505000, Epsilon: 0.01, Avg. Reward per Ep: 10.67
# Episodes: 279, Steps: 510000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 282, Steps: 515000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 285, Steps: 520000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 287, Steps: 525000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 290, Steps: 530000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 292, Steps: 535000, Epsilon: 0.01, Avg. Reward per Ep: -5.00
# Episodes: 295, Steps: 540000, Epsilon: 0.01, Avg. Reward per Ep: 2.00
# Episodes: 297, Steps: 545000, Epsilon: 0.01, Avg. Reward per Ep: 9.50
# Episodes: 300, Steps: 550000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 302, Steps: 555000, Epsilon: 0.01, Avg. Reward per Ep: 5.50
# Episodes: 305, Steps: 560000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 307, Steps: 565000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 310, Steps: 570000, Epsilon: 0.01, Avg. Reward per Ep: 5.00
# Episodes: 312, Steps: 575000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 315, Steps: 580000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 318, Steps: 585000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 321, Steps: 590000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 323, Steps: 595000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 326, Steps: 600000, Epsilon: 0.01, Avg. Reward per Ep: 20.00
# Episodes: 329, Steps: 605000, Epsilon: 0.01, Avg. Reward per Ep: 9.67
# Episodes: 331, Steps: 610000, Epsilon: 0.01, Avg. Reward per Ep: 9.00
# Episodes: 334, Steps: 615000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 337, Steps: 620000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 340, Steps: 625000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 342, Steps: 630000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 345, Steps: 635000, Epsilon: 0.01, Avg. Reward per Ep: 5.33
# Episodes: 348, Steps: 640000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 350, Steps: 645000, Epsilon: 0.01, Avg. Reward per Ep: 7.50
# Episodes: 352, Steps: 650000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 355, Steps: 655000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 358, Steps: 660000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 360, Steps: 665000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 363, Steps: 670000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 366, Steps: 675000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 368, Steps: 680000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 371, Steps: 685000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 374, Steps: 690000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 376, Steps: 695000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 378, Steps: 700000, Epsilon: 0.01, Avg. Reward per Ep: 4.50
# Episodes: 381, Steps: 705000, Epsilon: 0.01, Avg. Reward per Ep: 20.00
# Episodes: 384, Steps: 710000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 386, Steps: 715000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 389, Steps: 720000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 391, Steps: 725000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 394, Steps: 730000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 397, Steps: 735000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 399, Steps: 740000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 402, Steps: 745000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 404, Steps: 750000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 407, Steps: 755000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 410, Steps: 760000, Epsilon: 0.01, Avg. Reward per Ep: 2.67
# Episodes: 413, Steps: 765000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 416, Steps: 770000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 419, Steps: 775000, Epsilon: 0.01, Avg. Reward per Ep: 20.00
# Episodes: 421, Steps: 780000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 424, Steps: 785000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 427, Steps: 790000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 429, Steps: 795000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 432, Steps: 800000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 434, Steps: 805000, Epsilon: 0.01, Avg. Reward per Ep: 20.00
# Episodes: 437, Steps: 810000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 440, Steps: 815000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 442, Steps: 820000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 445, Steps: 825000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 448, Steps: 830000, Epsilon: 0.01, Avg. Reward per Ep: 10.00
# Episodes: 450, Steps: 835000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 453, Steps: 840000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 456, Steps: 845000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 458, Steps: 850000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 461, Steps: 855000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 463, Steps: 860000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 466, Steps: 865000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 468, Steps: 870000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 471, Steps: 875000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 473, Steps: 880000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 476, Steps: 885000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 478, Steps: 890000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 481, Steps: 895000, Epsilon: 0.01, Avg. Reward per Ep: 8.67
# Episodes: 483, Steps: 900000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 486, Steps: 905000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 488, Steps: 910000, Epsilon: 0.01, Avg. Reward per Ep: 3.50
# Episodes: 491, Steps: 915000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 494, Steps: 920000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 496, Steps: 925000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 499, Steps: 930000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 502, Steps: 935000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 504, Steps: 940000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 507, Steps: 945000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 509, Steps: 950000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 512, Steps: 955000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 515, Steps: 960000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 518, Steps: 965000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 520, Steps: 970000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 523, Steps: 975000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 526, Steps: 980000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 528, Steps: 985000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 531, Steps: 990000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 533, Steps: 995000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 535, Steps: 1000000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 538, Steps: 1005000, Epsilon: 0.01, Avg. Reward per Ep: 12.67
# Episodes: 541, Steps: 1010000, Epsilon: 0.01, Avg. Reward per Ep: 10.00
# Episodes: 544, Steps: 1015000, Epsilon: 0.01, Avg. Reward per Ep: 9.00
# Episodes: 546, Steps: 1020000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 549, Steps: 1025000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 551, Steps: 1030000, Epsilon: 0.01, Avg. Reward per Ep: 9.50
# Episodes: 554, Steps: 1035000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 556, Steps: 1040000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 559, Steps: 1045000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 562, Steps: 1050000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 564, Steps: 1055000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 566, Steps: 1060000, Epsilon: 0.01, Avg. Reward per Ep: 8.00
# Episodes: 569, Steps: 1065000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 572, Steps: 1070000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 575, Steps: 1075000, Epsilon: 0.01, Avg. Reward per Ep: 8.67
# Episodes: 578, Steps: 1080000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 580, Steps: 1085000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 583, Steps: 1090000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 585, Steps: 1095000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 588, Steps: 1100000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 591, Steps: 1105000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 593, Steps: 1110000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 596, Steps: 1115000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 599, Steps: 1120000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 602, Steps: 1125000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 605, Steps: 1130000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 607, Steps: 1135000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 610, Steps: 1140000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 612, Steps: 1145000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 615, Steps: 1150000, Epsilon: 0.01, Avg. Reward per Ep: 11.67
# Episodes: 617, Steps: 1155000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 620, Steps: 1160000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 623, Steps: 1165000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 626, Steps: 1170000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 628, Steps: 1175000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 631, Steps: 1180000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 633, Steps: 1185000, Epsilon: 0.01, Avg. Reward per Ep: 8.50
# Episodes: 636, Steps: 1190000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 638, Steps: 1195000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 641, Steps: 1200000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 644, Steps: 1205000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 646, Steps: 1210000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 649, Steps: 1215000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 651, Steps: 1220000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 654, Steps: 1225000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 657, Steps: 1230000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 659, Steps: 1235000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 662, Steps: 1240000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 664, Steps: 1245000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 667, Steps: 1250000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 669, Steps: 1255000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 672, Steps: 1260000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 675, Steps: 1265000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 678, Steps: 1270000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 680, Steps: 1275000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 683, Steps: 1280000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 686, Steps: 1285000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 689, Steps: 1290000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 691, Steps: 1295000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 694, Steps: 1300000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 697, Steps: 1305000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 699, Steps: 1310000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 702, Steps: 1315000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 704, Steps: 1320000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 707, Steps: 1325000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 709, Steps: 1330000, Epsilon: 0.01, Avg. Reward per Ep: 7.50
# Episodes: 711, Steps: 1335000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 714, Steps: 1340000, Epsilon: 0.01, Avg. Reward per Ep: 11.67
# Episodes: 716, Steps: 1345000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 719, Steps: 1350000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 721, Steps: 1355000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 724, Steps: 1360000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 726, Steps: 1365000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 729, Steps: 1370000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 732, Steps: 1375000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 734, Steps: 1380000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 737, Steps: 1385000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 740, Steps: 1390000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 743, Steps: 1395000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 746, Steps: 1400000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 748, Steps: 1405000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 751, Steps: 1410000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 753, Steps: 1415000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 756, Steps: 1420000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 758, Steps: 1425000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 761, Steps: 1430000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 764, Steps: 1435000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 766, Steps: 1440000, Epsilon: 0.01, Avg. Reward per Ep: 9.50
# Episodes: 768, Steps: 1445000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 771, Steps: 1450000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 774, Steps: 1455000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 777, Steps: 1460000, Epsilon: 0.01, Avg. Reward per Ep: 0.67
# Episodes: 779, Steps: 1465000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 782, Steps: 1470000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 785, Steps: 1475000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 787, Steps: 1480000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 790, Steps: 1485000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 793, Steps: 1490000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 795, Steps: 1495000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 798, Steps: 1500000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 801, Steps: 1505000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 803, Steps: 1510000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 806, Steps: 1515000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 808, Steps: 1520000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 811, Steps: 1525000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 813, Steps: 1530000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 816, Steps: 1535000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 819, Steps: 1540000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 822, Steps: 1545000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 824, Steps: 1550000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 827, Steps: 1555000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 830, Steps: 1560000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 833, Steps: 1565000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 835, Steps: 1570000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 838, Steps: 1575000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 840, Steps: 1580000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 843, Steps: 1585000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 845, Steps: 1590000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 848, Steps: 1595000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 851, Steps: 1600000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 853, Steps: 1605000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 856, Steps: 1610000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 859, Steps: 1615000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 862, Steps: 1620000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 865, Steps: 1625000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 868, Steps: 1630000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 870, Steps: 1635000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 873, Steps: 1640000, Epsilon: 0.01, Avg. Reward per Ep: 8.33
# Episodes: 875, Steps: 1645000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 878, Steps: 1650000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 881, Steps: 1655000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 884, Steps: 1660000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 886, Steps: 1665000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 889, Steps: 1670000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 892, Steps: 1675000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 895, Steps: 1680000, Epsilon: 0.01, Avg. Reward per Ep: 5.33
# Episodes: 898, Steps: 1685000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 900, Steps: 1690000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 903, Steps: 1695000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 906, Steps: 1700000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 908, Steps: 1705000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 911, Steps: 1710000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 914, Steps: 1715000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 917, Steps: 1720000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 919, Steps: 1725000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 922, Steps: 1730000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 925, Steps: 1735000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 928, Steps: 1740000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 930, Steps: 1745000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 933, Steps: 1750000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 936, Steps: 1755000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 939, Steps: 1760000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 941, Steps: 1765000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 944, Steps: 1770000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 946, Steps: 1775000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 949, Steps: 1780000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 952, Steps: 1785000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 954, Steps: 1790000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 957, Steps: 1795000, Epsilon: 0.01, Avg. Reward per Ep: 13.67
# Episodes: 960, Steps: 1800000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 963, Steps: 1805000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 965, Steps: 1810000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 968, Steps: 1815000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 971, Steps: 1820000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 974, Steps: 1825000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 976, Steps: 1830000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 979, Steps: 1835000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 982, Steps: 1840000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 984, Steps: 1845000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 987, Steps: 1850000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 990, Steps: 1855000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 993, Steps: 1860000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 995, Steps: 1865000, Epsilon: 0.01, Avg. Reward per Ep: 10.00
# Episodes: 998, Steps: 1870000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1001, Steps: 1875000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1003, Steps: 1880000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 1006, Steps: 1885000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1009, Steps: 1890000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1012, Steps: 1895000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1014, Steps: 1900000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1017, Steps: 1905000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1019, Steps: 1910000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1022, Steps: 1915000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1025, Steps: 1920000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1027, Steps: 1925000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1030, Steps: 1930000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1033, Steps: 1935000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1035, Steps: 1940000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1038, Steps: 1945000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1041, Steps: 1950000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1043, Steps: 1955000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1046, Steps: 1960000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1049, Steps: 1965000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1051, Steps: 1970000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1054, Steps: 1975000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1056, Steps: 1980000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1059, Steps: 1985000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1062, Steps: 1990000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1065, Steps: 1995000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 1067, Steps: 2000000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1070, Steps: 2005000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1073, Steps: 2010000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1075, Steps: 2015000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 1078, Steps: 2020000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1080, Steps: 2025000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1083, Steps: 2030000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1085, Steps: 2035000, Epsilon: 0.01, Avg. Reward per Ep: 6.00
# Episodes: 1088, Steps: 2040000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1090, Steps: 2045000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1093, Steps: 2050000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1096, Steps: 2055000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1099, Steps: 2060000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1101, Steps: 2065000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1103, Steps: 2070000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 1106, Steps: 2075000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1109, Steps: 2080000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1112, Steps: 2085000, Epsilon: 0.01, Avg. Reward per Ep: 5.33
# Episodes: 1115, Steps: 2090000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1117, Steps: 2095000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1120, Steps: 2100000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 1123, Steps: 2105000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1125, Steps: 2110000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1128, Steps: 2115000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1131, Steps: 2120000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1133, Steps: 2125000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1136, Steps: 2130000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1139, Steps: 2135000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1142, Steps: 2140000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1145, Steps: 2145000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1147, Steps: 2150000, Epsilon: 0.01, Avg. Reward per Ep: 11.50
# Episodes: 1150, Steps: 2155000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1153, Steps: 2160000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1155, Steps: 2165000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1158, Steps: 2170000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1161, Steps: 2175000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1163, Steps: 2180000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1166, Steps: 2185000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1169, Steps: 2190000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1172, Steps: 2195000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1174, Steps: 2200000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1177, Steps: 2205000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1180, Steps: 2210000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1182, Steps: 2215000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1185, Steps: 2220000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1188, Steps: 2225000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1191, Steps: 2230000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1193, Steps: 2235000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1196, Steps: 2240000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1198, Steps: 2245000, Epsilon: 0.01, Avg. Reward per Ep: 8.50
# Episodes: 1201, Steps: 2250000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1203, Steps: 2255000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1206, Steps: 2260000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1209, Steps: 2265000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1212, Steps: 2270000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1214, Steps: 2275000, Epsilon: 0.01, Avg. Reward per Ep: 7.50
# Episodes: 1217, Steps: 2280000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1220, Steps: 2285000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1222, Steps: 2290000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1225, Steps: 2295000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1227, Steps: 2300000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1230, Steps: 2305000, Epsilon: 0.01, Avg. Reward per Ep: 13.67
# Episodes: 1233, Steps: 2310000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1236, Steps: 2315000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1238, Steps: 2320000, Epsilon: 0.01, Avg. Reward per Ep: 10.50
# Episodes: 1241, Steps: 2325000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1243, Steps: 2330000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 1246, Steps: 2335000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1249, Steps: 2340000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1252, Steps: 2345000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1254, Steps: 2350000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1257, Steps: 2355000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1260, Steps: 2360000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1263, Steps: 2365000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1265, Steps: 2370000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1268, Steps: 2375000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1271, Steps: 2380000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1273, Steps: 2385000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1276, Steps: 2390000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1279, Steps: 2395000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1281, Steps: 2400000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1284, Steps: 2405000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1287, Steps: 2410000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1290, Steps: 2415000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1292, Steps: 2420000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1295, Steps: 2425000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1298, Steps: 2430000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1300, Steps: 2435000, Epsilon: 0.01, Avg. Reward per Ep: 11.50
# Episodes: 1303, Steps: 2440000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1305, Steps: 2445000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1308, Steps: 2450000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1310, Steps: 2455000, Epsilon: 0.01, Avg. Reward per Ep: 12.50
# Episodes: 1313, Steps: 2460000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1315, Steps: 2465000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 1318, Steps: 2470000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1320, Steps: 2475000, Epsilon: 0.01, Avg. Reward per Ep: 5.00
# Episodes: 1322, Steps: 2480000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1325, Steps: 2485000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1328, Steps: 2490000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1330, Steps: 2495000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1333, Steps: 2500000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 1335, Steps: 2505000, Epsilon: 0.01, Avg. Reward per Ep: 11.50
# Episodes: 1337, Steps: 2510000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 1340, Steps: 2515000, Epsilon: 0.01, Avg. Reward per Ep: 13.67
# Episodes: 1343, Steps: 2520000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1345, Steps: 2525000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1348, Steps: 2530000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1351, Steps: 2535000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1353, Steps: 2540000, Epsilon: 0.01, Avg. Reward per Ep: 10.00
# Episodes: 1356, Steps: 2545000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1358, Steps: 2550000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1361, Steps: 2555000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1364, Steps: 2560000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1367, Steps: 2565000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1369, Steps: 2570000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1372, Steps: 2575000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1375, Steps: 2580000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1377, Steps: 2585000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1380, Steps: 2590000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1383, Steps: 2595000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1386, Steps: 2600000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 1388, Steps: 2605000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 1390, Steps: 2610000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1393, Steps: 2615000, Epsilon: 0.01, Avg. Reward per Ep: 5.67
# Episodes: 1396, Steps: 2620000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1398, Steps: 2625000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1401, Steps: 2630000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1404, Steps: 2635000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1407, Steps: 2640000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1409, Steps: 2645000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1412, Steps: 2650000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1415, Steps: 2655000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1418, Steps: 2660000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1421, Steps: 2665000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1424, Steps: 2670000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1426, Steps: 2675000, Epsilon: 0.01, Avg. Reward per Ep: 11.50
# Episodes: 1428, Steps: 2680000, Epsilon: 0.01, Avg. Reward per Ep: 9.00
# Episodes: 1431, Steps: 2685000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1433, Steps: 2690000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1436, Steps: 2695000, Epsilon: 0.01, Avg. Reward per Ep: 6.00
# Episodes: 1439, Steps: 2700000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1441, Steps: 2705000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 1444, Steps: 2710000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1447, Steps: 2715000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1449, Steps: 2720000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1452, Steps: 2725000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1455, Steps: 2730000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1457, Steps: 2735000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1460, Steps: 2740000, Epsilon: 0.01, Avg. Reward per Ep: 10.33
# Episodes: 1462, Steps: 2745000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1464, Steps: 2750000, Epsilon: 0.01, Avg. Reward per Ep: 8.50
# Episodes: 1467, Steps: 2755000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 1469, Steps: 2760000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1472, Steps: 2765000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1475, Steps: 2770000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1478, Steps: 2775000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1481, Steps: 2780000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1483, Steps: 2785000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1486, Steps: 2790000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1489, Steps: 2795000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1492, Steps: 2800000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1495, Steps: 2805000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1497, Steps: 2810000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1500, Steps: 2815000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1503, Steps: 2820000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1506, Steps: 2825000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1509, Steps: 2830000, Epsilon: 0.01, Avg. Reward per Ep: 20.00
# Episodes: 1511, Steps: 2835000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1514, Steps: 2840000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1517, Steps: 2845000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1519, Steps: 2850000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1522, Steps: 2855000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1525, Steps: 2860000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1528, Steps: 2865000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1530, Steps: 2870000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1533, Steps: 2875000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1536, Steps: 2880000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1539, Steps: 2885000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1542, Steps: 2890000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1545, Steps: 2895000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1548, Steps: 2900000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1551, Steps: 2905000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1553, Steps: 2910000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 1555, Steps: 2915000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1558, Steps: 2920000, Epsilon: 0.01, Avg. Reward per Ep: 9.67
# Episodes: 1560, Steps: 2925000, Epsilon: 0.01, Avg. Reward per Ep: 8.00
# Episodes: 1563, Steps: 2930000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1565, Steps: 2935000, Epsilon: 0.01, Avg. Reward per Ep: 11.50
# Episodes: 1568, Steps: 2940000, Epsilon: 0.01, Avg. Reward per Ep: 11.67
# Episodes: 1570, Steps: 2945000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 1573, Steps: 2950000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1576, Steps: 2955000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1578, Steps: 2960000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1581, Steps: 2965000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1584, Steps: 2970000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1586, Steps: 2975000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 1589, Steps: 2980000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1592, Steps: 2985000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1595, Steps: 2990000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1598, Steps: 2995000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1601, Steps: 3000000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1603, Steps: 3005000, Epsilon: 0.01, Avg. Reward per Ep: 19.50
# Episodes: 1606, Steps: 3010000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1609, Steps: 3015000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1612, Steps: 3020000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1615, Steps: 3025000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1618, Steps: 3030000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1620, Steps: 3035000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1623, Steps: 3040000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1626, Steps: 3045000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1628, Steps: 3050000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1631, Steps: 3055000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1634, Steps: 3060000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1637, Steps: 3065000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1639, Steps: 3070000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1642, Steps: 3075000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1645, Steps: 3080000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1647, Steps: 3085000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1650, Steps: 3090000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1653, Steps: 3095000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1655, Steps: 3100000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1658, Steps: 3105000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1660, Steps: 3110000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1663, Steps: 3115000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1666, Steps: 3120000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1668, Steps: 3125000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1671, Steps: 3130000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1674, Steps: 3135000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1676, Steps: 3140000, Epsilon: 0.01, Avg. Reward per Ep: 9.00
# Episodes: 1679, Steps: 3145000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 1682, Steps: 3150000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1685, Steps: 3155000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1687, Steps: 3160000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 1690, Steps: 3165000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1692, Steps: 3170000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1695, Steps: 3175000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1698, Steps: 3180000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1700, Steps: 3185000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 1703, Steps: 3190000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1706, Steps: 3195000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1708, Steps: 3200000, Epsilon: 0.01, Avg. Reward per Ep: 9.50
# Episodes: 1711, Steps: 3205000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1714, Steps: 3210000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1715, Steps: 3215000, Epsilon: 0.01, Avg. Reward per Ep: 4.00
# Episodes: 1718, Steps: 3220000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 1721, Steps: 3225000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1724, Steps: 3230000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1726, Steps: 3235000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1729, Steps: 3240000, Epsilon: 0.01, Avg. Reward per Ep: 13.67
# Episodes: 1732, Steps: 3245000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1735, Steps: 3250000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1737, Steps: 3255000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1740, Steps: 3260000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1743, Steps: 3265000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1746, Steps: 3270000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1748, Steps: 3275000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1751, Steps: 3280000, Epsilon: 0.01, Avg. Reward per Ep: 6.00
# Episodes: 1754, Steps: 3285000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1757, Steps: 3290000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 1760, Steps: 3295000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1762, Steps: 3300000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1765, Steps: 3305000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 1767, Steps: 3310000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1770, Steps: 3315000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1772, Steps: 3320000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 1775, Steps: 3325000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1778, Steps: 3330000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1780, Steps: 3335000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1783, Steps: 3340000, Epsilon: 0.01, Avg. Reward per Ep: 8.67
# Episodes: 1785, Steps: 3345000, Epsilon: 0.01, Avg. Reward per Ep: 3.50
# Episodes: 1787, Steps: 3350000, Epsilon: 0.01, Avg. Reward per Ep: 6.00
# Episodes: 1789, Steps: 3355000, Epsilon: 0.01, Avg. Reward per Ep: 12.00
# Episodes: 1792, Steps: 3360000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 1794, Steps: 3365000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1797, Steps: 3370000, Epsilon: 0.01, Avg. Reward per Ep: 11.33
# Episodes: 1800, Steps: 3375000, Epsilon: 0.01, Avg. Reward per Ep: 16.33
# Episodes: 1803, Steps: 3380000, Epsilon: 0.01, Avg. Reward per Ep: 19.67
# Episodes: 1805, Steps: 3385000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1808, Steps: 3390000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1811, Steps: 3395000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1814, Steps: 3400000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1816, Steps: 3405000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1819, Steps: 3410000, Epsilon: 0.01, Avg. Reward per Ep: 13.00
# Episodes: 1821, Steps: 3415000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1824, Steps: 3420000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1827, Steps: 3425000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1830, Steps: 3430000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1833, Steps: 3435000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1835, Steps: 3440000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1838, Steps: 3445000, Epsilon: 0.01, Avg. Reward per Ep: 12.33
# Episodes: 1840, Steps: 3450000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 1843, Steps: 3455000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1845, Steps: 3460000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1848, Steps: 3465000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1851, Steps: 3470000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1854, Steps: 3475000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1856, Steps: 3480000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# Episodes: 1859, Steps: 3485000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1862, Steps: 3490000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1865, Steps: 3495000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1867, Steps: 3500000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1870, Steps: 3505000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1873, Steps: 3510000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1876, Steps: 3515000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 1878, Steps: 3520000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1881, Steps: 3525000, Epsilon: 0.01, Avg. Reward per Ep: 13.67
# Episodes: 1883, Steps: 3530000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1886, Steps: 3535000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1889, Steps: 3540000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1891, Steps: 3545000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1894, Steps: 3550000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1897, Steps: 3555000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1900, Steps: 3560000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1902, Steps: 3565000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1905, Steps: 3570000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1908, Steps: 3575000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1911, Steps: 3580000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1914, Steps: 3585000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1916, Steps: 3590000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1919, Steps: 3595000, Epsilon: 0.01, Avg. Reward per Ep: 11.00
# Episodes: 1922, Steps: 3600000, Epsilon: 0.01, Avg. Reward per Ep: 16.67
# Episodes: 1924, Steps: 3605000, Epsilon: 0.01, Avg. Reward per Ep: 17.50
# Episodes: 1927, Steps: 3610000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1930, Steps: 3615000, Epsilon: 0.01, Avg. Reward per Ep: 15.67
# Episodes: 1932, Steps: 3620000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1935, Steps: 3625000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 1938, Steps: 3630000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1941, Steps: 3635000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1943, Steps: 3640000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1946, Steps: 3645000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1948, Steps: 3650000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 1951, Steps: 3655000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1954, Steps: 3660000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1957, Steps: 3665000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1959, Steps: 3670000, Epsilon: 0.01, Avg. Reward per Ep: 19.00
# Episodes: 1962, Steps: 3675000, Epsilon: 0.01, Avg. Reward per Ep: 13.33
# Episodes: 1965, Steps: 3680000, Epsilon: 0.01, Avg. Reward per Ep: 19.33
# Episodes: 1968, Steps: 3685000, Epsilon: 0.01, Avg. Reward per Ep: 18.33
# Episodes: 1970, Steps: 3690000, Epsilon: 0.01, Avg. Reward per Ep: 10.50
# Episodes: 1973, Steps: 3695000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1975, Steps: 3700000, Epsilon: 0.01, Avg. Reward per Ep: 14.50
# Episodes: 1978, Steps: 3705000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 1981, Steps: 3710000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 1983, Steps: 3715000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 1986, Steps: 3720000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 1989, Steps: 3725000, Epsilon: 0.01, Avg. Reward per Ep: 18.00
# Episodes: 1992, Steps: 3730000, Epsilon: 0.01, Avg. Reward per Ep: 18.67
# Episodes: 1994, Steps: 3735000, Epsilon: 0.01, Avg. Reward per Ep: 16.50
# Episodes: 1997, Steps: 3740000, Epsilon: 0.01, Avg. Reward per Ep: 15.00
# Episodes: 2000, Steps: 3745000, Epsilon: 0.01, Avg. Reward per Ep: 17.33
# Episodes: 2002, Steps: 3750000, Epsilon: 0.01, Avg. Reward per Ep: 13.50
# Episodes: 2005, Steps: 3755000, Epsilon: 0.01, Avg. Reward per Ep: 17.67
# Episodes: 2008, Steps: 3760000, Epsilon: 0.01, Avg. Reward per Ep: 17.00
# Episodes: 2010, Steps: 3765000, Epsilon: 0.01, Avg. Reward per Ep: 14.00
# Episodes: 2013, Steps: 3770000, Epsilon: 0.01, Avg. Reward per Ep: 14.67
# Episodes: 2015, Steps: 3775000, Epsilon: 0.01, Avg. Reward per Ep: 16.00
# Episodes: 2018, Steps: 3780000, Epsilon: 0.01, Avg. Reward per Ep: 15.33
# Episodes: 2020, Steps: 3785000, Epsilon: 0.01, Avg. Reward per Ep: 15.50
# Episodes: 2023, Steps: 3790000, Epsilon: 0.01, Avg. Reward per Ep: 14.33
# Episodes: 2025, Steps: 3795000, Epsilon: 0.01, Avg. Reward per Ep: 18.50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-49f0488627db> in <module>()
# ----> 1 s, ns = agent.train()
#
# <ipython-input-8-4d8cbfefdf63> in train(self)
#     127                 #update model parameters
#     128                 if mem.is_available() and self.steps % self.update_freq == 0 and self.steps > 10_000:
# --> 129                     loss = self.optimize()
#     130
#     131                 if self.steps % (self.target_update*self.update_freq) == 0 and self.steps > 10_000:
#
# <ipython-input-8-4d8cbfefdf63> in optimize(self)
#     162
#     163         #action_batch = (N, 1)
# --> 164         action_batch = torch.cat(transitions.action).unsqueeze(1).to(device)
#     165
#     166         #reward_batch = (N, 1)
#
# KeyboardInterrupt:

# %%
plt.imshow(s[1,:,:])

# %%
plt.imshow(s[2,:,:])

# %%
plt.imshow(s[3,:,:])
